# %% [markdown]
# <img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY" style="display:block; margin:auto; border:0px solid red;" width=50% height='250'/>
#
# <p style="background-color:romance; color:plum; text-align:center; border-radius:10px 10px; font-family:newtimeroman; font-weight:bold; font-size:220%; line-height:1.4; text-transform: uppercase;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# **WELCOME!**
#
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# **Determines**
#
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# <a id="0">**TASKS**</a>
#
# 01. Exploratory Data Analysis (EDA)
#     - Import Libraries, Load Dataset, Exploring Data
#       1. *i. Import Libraries*
#       2. *ii. Ingest Data*
#       3. *iii. Explore Data*
#       4. *iv. Outlier Detection*
#       5. *v.  Drop unnecessary features*
# 02. Data Preprocessing
#     + Scale (if needed)
#     + Separete the data frame for evaluation purposes
# 03. Multi-class Classification
#     * Import libraries
#     * Implement SVM Classifer
#     * Implement Decision Tree Classifier
#     * Implement Random Forest Classifer
#     * Implement XGBoost Classifer
#     * Compare The Models

# %% [markdown]
# <a id="1"></a>
#
# # EDA
#
# <!-- <a href="#0" class="btn btn-primary btn-sm" role="button" aria-pressed="true" data-toggle="popover" style="background-color:DarkOrange; color:White;">**Tasks**</a> -->
#
# - Drop unnecessary colums
# - Drop **DODRace** class if **`value count below 500`** (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# !pip install skimpy
from skimpy import clean_columns
import scipy.stats as stats
from scipy.stats import skew, kurtosis

# to get rid of the warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# Environment settings: 
pd.set_option('display.float_format', lambda x: f'{x:.4f}')
# pd.set_option('display.float_format', lambda x: '%.6f'%x)
# pd.options.display.float_format = '{:.3f}'.format
# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)
# Set it None to display all rows in the dataframe
pd.set_option('display.max_rows', 100)

# %%
# The style parameters control properties like the color of the background and whether a grid is enabled by default.
sns.set_style("whitegrid", {'axes.grid' : False})

params = {
'figure.figsize':(12,6),
'figure.titlesize':20,
'font.size': 15,
'axes.titlesize': 20,
'axes.labelsize': 15,
'xtick.labelsize': 15,
'ytick.labelsize': 15,
'legend.fontsize': 15,
'boxplot.showmeans': True,
'boxplot.meanprops.marker': 'o',
'boxplot.meanprops.markeredgecolor': 'k',
'boxplot.meanprops.markerfacecolor': 'r',
'boxplot.meanprops.markersize': 10.1,
'boxplot.medianprops.color': 'r',
'boxplot.medianprops.linewidth': 2.0,
}
plt.rcParams.update(params)
# plt.rcParams.update(plt.rcParamsDefault)
# print(plt.style.library)
# print(plt.rcParams['figure.figsize'])

# %%
random_state=42

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df_female_origin = pd.read_csv('https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq')
df_female = df_female_origin.copy()
df_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %%
df_male_origin = pd.read_csv('https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr', encoding='unicode_escape')
df_male = df_male_origin.copy()
df_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           70         332                366                1071
# 1           72         312                356                1046
# 2           70         349                393                1053
# 3           68         338                367                 986
# 4           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    685         422          441                   502
# 1                    620         441          447                   490
# 2                    665         462          475                   496
# 3                    640         458          461                   460
# 4                    675         481          505                   612
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                560                             500                      77
# 1                540                             488                      73
# 2                556                             482                      72
# 3                511                             452                      76
# 4                666                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
df_female.shape, df_male.shape
# Out:
# ((1986, 108), (4082, 108))

# %%
df_female.info(), df_male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Columns: 108 entries, SubjectId to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 1.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Columns: 108 entries, subjectid to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 3.4+ MB
# (None, None)

# %%
df_male.info(max_cols=110)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Data columns (total 108 columns):
#  #    Column                          Non-Null Count  Dtype
# ---   ------                          --------------  -----
#  0    subjectid                       4082 non-null   int64
#  1    abdominalextensiondepthsitting  4082 non-null   int64
#  2    acromialheight                  4082 non-null   int64
#  3    acromionradialelength           4082 non-null   int64
#  4    anklecircumference              4082 non-null   int64
#  5    axillaheight                    4082 non-null   int64
#  6    balloffootcircumference         4082 non-null   int64
#  7    balloffootlength                4082 non-null   int64
#  8    biacromialbreadth               4082 non-null   int64
#  9    bicepscircumferenceflexed       4082 non-null   int64
#  10   bicristalbreadth                4082 non-null   int64
#  11   bideltoidbreadth                4082 non-null   int64
#  12   bimalleolarbreadth              4082 non-null   int64
#  13   bitragionchinarc                4082 non-null   int64
#  14   bitragionsubmandibulararc       4082 non-null   int64
#  15   bizygomaticbreadth              4082 non-null   int64
#  16   buttockcircumference            4082 non-null   int64
#  17   buttockdepth                    4082 non-null   int64
#  18   buttockheight                   4082 non-null   int64
#  19   buttockkneelength               4082 non-null   int64
#  20   buttockpopliteallength          4082 non-null   int64
#  21   calfcircumference               4082 non-null   int64
#  22   cervicaleheight                 4082 non-null   int64
#  23   chestbreadth                    4082 non-null   int64
#  24   chestcircumference              4082 non-null   int64
#  25   chestdepth                      4082 non-null   int64
#  26   chestheight                     4082 non-null   int64
#  27   crotchheight                    4082 non-null   int64
#  28   crotchlengthomphalion           4082 non-null   int64
#  29   crotchlengthposterioromphalion  4082 non-null   int64
#  30   earbreadth                      4082 non-null   int64
#  31   earlength                       4082 non-null   int64
#  32   earprotrusion                   4082 non-null   int64
#  33   elbowrestheight                 4082 non-null   int64
#  34   eyeheightsitting                4082 non-null   int64
#  35   footbreadthhorizontal           4082 non-null   int64
#  36   footlength                      4082 non-null   int64
#  37   forearmcenterofgriplength       4082 non-null   int64
#  38   forearmcircumferenceflexed      4082 non-null   int64
#  39   forearmforearmbreadth           4082 non-null   int64
#  40   forearmhandlength               4082 non-null   int64
#  41   functionalleglength             4082 non-null   int64
#  42   handbreadth                     4082 non-null   int64
#  43   handcircumference               4082 non-null   int64
#  44   handlength                      4082 non-null   int64
#  45   headbreadth                     4082 non-null   int64
#  46   headcircumference               4082 non-null   int64
#  47   headlength                      4082 non-null   int64
#  48   heelanklecircumference          4082 non-null   int64
#  49   heelbreadth                     4082 non-null   int64
#  50   hipbreadth                      4082 non-null   int64
#  51   hipbreadthsitting               4082 non-null   int64
#  52   iliocristaleheight              4082 non-null   int64
#  53   interpupillarybreadth           4082 non-null   int64
#  54   interscyei                      4082 non-null   int64
#  55   interscyeii                     4082 non-null   int64
#  56   kneeheightmidpatella            4082 non-null   int64
#  57   kneeheightsitting               4082 non-null   int64
#  58   lateralfemoralepicondyleheight  4082 non-null   int64
#  59   lateralmalleolusheight          4082 non-null   int64
#  60   lowerthighcircumference         4082 non-null   int64
#  61   mentonsellionlength             4082 non-null   int64
#  62   neckcircumference               4082 non-null   int64
#  63   neckcircumferencebase           4082 non-null   int64
#  64   overheadfingertipreachsitting   4082 non-null   int64
#  65   palmlength                      4082 non-null   int64
#  66   poplitealheight                 4082 non-null   int64
#  67   radialestylionlength            4082 non-null   int64
#  68   shouldercircumference           4082 non-null   int64
#  69   shoulderelbowlength             4082 non-null   int64
#  70   shoulderlength                  4082 non-null   int64
#  71   sittingheight                   4082 non-null   int64
#  72   sleevelengthspinewrist          4082 non-null   int64
#  73   sleeveoutseam                   4082 non-null   int64
#  74   span                            4082 non-null   int64
#  75   stature                         4082 non-null   int64
#  76   suprasternaleheight             4082 non-null   int64
#  77   tenthribheight                  4082 non-null   int64
#  78   thighcircumference              4082 non-null   int64
#  79   thighclearance                  4082 non-null   int64
#  80   thumbtipreach                   4082 non-null   int64
#  81   tibialheight                    4082 non-null   int64
#  82   tragiontopofhead                4082 non-null   int64
#  83   trochanterionheight             4082 non-null   int64
#  84   verticaltrunkcircumferenceusa   4082 non-null   int64
#  85   waistbacklength                 4082 non-null   int64
#  86   waistbreadth                    4082 non-null   int64
#  87   waistcircumference              4082 non-null   int64
#  88   waistdepth                      4082 non-null   int64
#  89   waistfrontlengthsitting         4082 non-null   int64
#  90   waistheightomphalion            4082 non-null   int64
#  91   weightkg                        4082 non-null   int64
#  92   wristcircumference              4082 non-null   int64
#  93   wristheight                     4082 non-null   int64
#  94   Gender                          4082 non-null   object
#  95   Date                            4082 non-null   object
#  96   Installation                    4082 non-null   object
#  97   Component                       4082 non-null   object
#  98   Branch                          4082 non-null   object
#  99   PrimaryMOS                      4082 non-null   object
#  100  SubjectsBirthLocation           4082 non-null   object
#  101  SubjectNumericRace              4082 non-null   int64
#  102  Ethnicity                       902 non-null    object
#  103  DODRace                         4082 non-null   int64
#  104  Age                             4082 non-null   int64
#  105  Heightin                        4082 non-null   int64
#  106  Weightlbs                       4082 non-null   int64
#  107  WritingPreference               4082 non-null   object
# dtypes: int64(99), object(9)
# memory usage: 3.4+ MB

# %% [markdown]
# ## Explore Data

# %% [markdown]
# ### If needed, rename the columns' names for easy use.

# %%
# df_female.columns==df_male.columns
df_female.rename(columns={'SubjectId':'subjectid'}, inplace=True)

# %%
df = pd.concat([df_female,df_male], ignore_index=True)

# %%
df.shape
# Out:
# (6068, 108)

# %%
# clean_columns(df)

# %% [markdown]
# ### Check if there are some dublicate rows or not. If there are, then drop them.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Basically check the missing values. (NaN, None)-(isna(), mean())

# %%
(df.isna().mean()*100).tail(10)
# Out:
# Branch                   0.0000
# PrimaryMOS               0.0000
# SubjectsBirthLocation    0.0000
# SubjectNumericRace       0.0000
# Ethnicity               76.5821
# DODRace                  0.0000
# Age                      0.0000
# Heightin                 0.0000
# Weightlbs                0.0000
# WritingPreference        0.0000
# dtype: float64

# %% [markdown]
# ### Check the statistical values of features.

# %%
df.describe(include='number').T
# Out:
#                                    count       mean        std        min  \
# subjectid                      6068.0000 20757.1984 13159.3909 10027.0000
# abdominalextensiondepthsitting 6068.0000   246.4687    37.4001   155.0000
# acromialheight                 6068.0000  1406.1613    79.0910  1115.0000
# acromionradialelength          6068.0000   327.3744    20.7200   249.0000
# anklecircumference             6068.0000   224.8914    16.0518   156.0000
# axillaheight                   6068.0000  1299.6088    72.0223  1038.0000
# balloffootcircumference        6068.0000   244.1926    16.8450   186.0000
# balloffootlength               6068.0000   194.7546    13.5164   151.0000
# biacromialbreadth              6068.0000   399.2042    30.2369   283.0000
# bicepscircumferenceflexed      6068.0000   340.9342    41.5199   216.0000
# bicristalbreadth               6068.0000   274.7350    19.2210   197.0000
# bideltoidbreadth               6068.0000   490.7544    42.1355   357.0000
# bimalleolarbreadth             6068.0000    72.2526     5.3446    55.0000
# bitragionchinarc               6068.0000   324.8965    17.0875   267.0000
# bitragionsubmandibulararc      6068.0000   306.6361    20.7942   245.0000
# bizygomaticbreadth             6068.0000   139.7235     7.3085   116.0000
# buttockcircumference           6068.0000  1020.0847    76.4226   737.0000
# buttockdepth                   6068.0000   241.6200    26.4830   168.0000
# buttockheight                  6068.0000   870.1523    54.8226   656.0000
# buttockkneelength              6068.0000   608.9992    33.7928   466.0000
# buttockpopliteallength         6068.0000   497.0976    29.0824   367.0000
# calfcircumference              6068.0000   386.0412    30.6472   266.0000
# cervicaleheight                6068.0000  1477.4904    84.3237  1184.0000
# chestbreadth                   6068.0000   282.8591    20.6594   213.0000
# chestcircumference             6068.0000  1022.0989   100.6718   695.0000
# chestdepth                     6068.0000   251.7385    26.7778   170.0000
# chestheight                    6068.0000  1252.0132    79.5840   984.0000
# crotchheight                   6068.0000   825.1101    54.7482   610.0000
# crotchlengthomphalion          6068.0000   621.8517    45.3330   473.0000
# crotchlengthposterioromphalion 6068.0000   351.3159    29.9449   243.0000
# earbreadth                     6068.0000    35.1322     3.2315    25.0000
# earlength                      6068.0000    62.6259     4.8763    46.0000
# earprotrusion                  6068.0000    22.2633     3.1727    13.0000
# elbowrestheight                6068.0000   240.9113    28.5094   138.0000
# eyeheightsitting               6068.0000   785.9145    41.8658   654.0000
# footbreadthhorizontal          6068.0000    98.8654     6.6579    77.0000
# footlength                     6068.0000   263.0336    17.3910   198.0000
# forearmcenterofgriplength      6068.0000   338.7666    23.2447   258.0000
# forearmcircumferenceflexed     6068.0000   295.0107    30.0497   200.0000
# forearmforearmbreadth          6068.0000   552.0760    62.3680   376.0000
# forearmhandlength              6068.0000   467.0071    30.0348   342.0000
# functionalleglength            6068.0000  1102.0493    68.5458   835.0000
# handbreadth                    6068.0000    84.9534     6.3465    67.0000
# handcircumference              6068.0000   203.8614    15.5514   152.0000
# handlength                     6068.0000   189.2866    11.5058   145.0000
# headbreadth                    6068.0000   152.1828     6.2357   131.0000
# headcircumference              6068.0000   570.0353    18.2911   500.0000
# headlength                     6068.0000   196.3349     8.4854   168.0000
# heelanklecircumference         6068.0000   332.6229    22.4608   258.0000
# heelbreadth                    6068.0000    70.7569     5.9326    48.0000
# hipbreadth                     6068.0000   348.3855    25.2978   264.0000
# hipbreadthsitting              6068.0000   385.7334    32.3999   280.0000
# iliocristaleheight             6068.0000  1040.0595    59.8670   816.0000
# interpupillarybreadth          6068.0000   632.6020    36.5090   510.0000
# interscyei                     6068.0000   412.0377    43.0659   270.0000
# interscyeii                    6068.0000   432.3408    38.6582   306.0000
# kneeheightmidpatella           6068.0000   475.5129    33.0747   346.0000
# kneeheightsitting              6068.0000   540.1249    34.2031   407.0000
# lateralfemoralepicondyleheight 6068.0000   483.2396    29.3596   352.0000
# lateralmalleolusheight         6068.0000    69.5804     7.2701    43.0000
# lowerthighcircumference        6068.0000   406.4799    33.2283   290.0000
# mentonsellionlength            6068.0000   119.5188     7.8799    91.0000
# neckcircumference              6068.0000   375.4412    39.7702   275.0000
# neckcircumferencebase          6068.0000   413.8347    38.1564   302.0000
# overheadfingertipreachsitting  6068.0000  1388.4044    85.8492  1111.0000
# palmlength                     6068.0000   113.9166     7.1366    88.0000
# poplitealheight                6068.0000   416.1870    31.2664   305.0000
# radialestylionlength           6068.0000   259.1923    19.7776   169.0000
# shouldercircumference          6068.0000  1129.3622    92.8288   852.0000
# shoulderelbowlength            6068.0000   354.0836    22.5986   271.0000
# shoulderlength                 6068.0000   145.0727    12.4243   107.0000
# sittingheight                  6068.0000   898.1078    45.2990   750.0000
# sleevelengthspinewrist         6068.0000   866.6653    57.5241   636.0000
# sleeveoutseam                  6068.0000   576.9000    38.2586   410.0000
# span                           6068.0000  1763.7948   110.8328  1323.0000
# stature                        6068.0000  1714.4061    90.0153  1409.0000
# suprasternaleheight            6068.0000  1402.9491    78.7681  1131.0000
# tenthribheight                 6068.0000  1099.5872    60.5409   868.0000
# thighcircumference             6068.0000   622.1987    57.7507   412.0000
# thighclearance                 6068.0000   176.3364    16.2203   121.0000
# thumbtipreach                  6068.0000   789.6956    53.8236   602.0000
# tibialheight                   6068.0000   458.2446    29.7593   344.0000
# tragiontopofhead               6068.0000   129.6180     6.6597   105.0000
# trochanterionheight            6068.0000   882.7399    54.4028   660.0000
# verticaltrunkcircumferenceusa  6068.0000  1630.3095    98.6241  1342.0000
# waistbacklength                6068.0000   460.5247    36.6779   345.0000
# waistbreadth                   6068.0000   317.7500    36.3631   211.0000
# waistcircumference             6068.0000   914.5015   114.2745   611.0000
# waistdepth                     6068.0000   229.6740    35.6132   138.0000
# waistfrontlengthsitting        6068.0000   377.0038    31.6177   289.0000
# waistheightomphalion           6068.0000  1031.5012    62.7024   805.0000
# weightkg                       6068.0000   797.0939   156.5282   358.0000
# wristcircumference             6068.0000   169.0030    13.1245   124.0000
# wristheight                    6068.0000   830.0600    47.6505   672.0000
# SubjectNumericRace             6068.0000    17.5153   550.9499     1.0000
# DODRace                        6068.0000     1.6150     0.9792     1.0000
# Age                            6068.0000    29.7612     8.6746    17.0000
# Heightin                       6068.0000    68.2573     3.8620    56.0000
# Weightlbs                      6068.0000   174.7497    33.6920     0.0000
#
#                                       25%        50%        75%         max
# subjectid                      14841.7500 20063.5000 27234.5000 920103.0000
# abdominalextensiondepthsitting   219.0000   242.0000   271.0000    451.0000
# acromialheight                  1350.0000  1410.0000  1462.0000   1683.0000
# acromionradialelength            313.0000   328.0000   341.2500    393.0000
# anklecircumference               214.0000   225.0000   235.0000    293.0000
# axillaheight                    1249.0000  1302.0000  1349.0000   1553.0000
# balloffootcircumference          232.0000   245.0000   256.0000    306.0000
# balloffootlength                 185.0000   195.0000   204.0000    245.0000
# biacromialbreadth                376.0000   404.0000   421.0000    489.0000
# bicepscircumferenceflexed        311.0000   341.0000   370.0000    490.0000
# bicristalbreadth                 262.0000   274.0000   288.0000    362.0000
# bideltoidbreadth                 460.0000   492.0000   520.0000    637.0000
# bimalleolarbreadth                68.0000    72.0000    76.0000     91.0000
# bitragionchinarc                 314.0000   326.0000   336.0000    385.0000
# bitragionsubmandibulararc        292.0000   307.0000   321.0000    390.0000
# bizygomaticbreadth               135.0000   140.0000   145.0000    174.0000
# buttockcircumference             968.0000  1017.0000  1068.0000   1341.0000
# buttockdepth                     222.0000   241.0000   259.0000    349.0000
# buttockheight                    832.0000   868.0000   906.2500   1080.0000
# buttockkneelength                586.0000   609.0000   632.0000    736.0000
# buttockpopliteallength           477.0000   497.0000   517.0000    605.0000
# calfcircumference                364.7500   385.0000   406.0000    523.0000
# cervicaleheight                 1418.0000  1484.0000  1537.0000   1738.0000
# chestbreadth                     268.0000   283.0000   297.0000    363.0000
# chestcircumference               949.0000  1020.5000  1092.0000   1469.0000
# chestdepth                       233.0000   251.0000   270.0000    383.0000
# chestheight                     1196.0000  1259.0000  1309.0000   1506.0000
# crotchheight                     787.0000   825.0000   863.0000   1031.0000
# crotchlengthomphalion            590.0000   620.0000   651.0000    799.0000
# crotchlengthposterioromphalion   330.0000   350.0000   372.0000    468.0000
# earbreadth                        33.0000    35.0000    37.0000     46.0000
# earlength                         59.0000    62.0000    66.0000     81.0000
# earprotrusion                     20.0000    22.0000    24.0000     34.0000
# elbowrestheight                  222.0000   241.0000   261.0000    345.0000
# eyeheightsitting                 757.0000   787.0000   815.0000    912.0000
# footbreadthhorizontal             94.0000    99.0000   104.0000    126.0000
# footlength                       251.0000   264.0000   276.0000    323.0000
# forearmcenterofgriplength        322.0000   340.0000   355.0000    416.0000
# forearmcircumferenceflexed       272.0000   297.0000   317.0000    402.0000
# forearmforearmbreadth            505.0000   553.0000   597.0000    778.0000
# forearmhandlength                446.0000   469.0000   488.0000    574.0000
# functionalleglength             1055.0000  1104.0000  1149.0000   1316.0000
# handbreadth                       80.0000    86.0000    90.0000    105.0000
# handcircumference                192.0000   206.0000   215.0000    248.0000
# handlength                       181.0000   189.5000   197.0000    239.0000
# headbreadth                      148.0000   152.0000   156.0000    180.0000
# headcircumference                557.0000   570.0000   582.0000    635.0000
# headlength                       191.0000   197.0000   202.0000    225.0000
# heelanklecircumference           316.0000   334.0000   348.0000    403.0000
# heelbreadth                       67.0000    70.0000    75.0000     93.0000
# hipbreadth                       332.0000   347.0000   364.0000    473.0000
# hipbreadthsitting                364.0000   384.0000   406.0000    541.0000
# iliocristaleheight               998.0000  1040.0000  1081.0000   1253.0000
# interpupillarybreadth            610.0000   635.0000   655.0000    770.0000
# interscyei                       381.0000   411.0000   442.0000    562.0000
# interscyeii                      405.0000   434.0000   460.0000    577.0000
# kneeheightmidpatella             452.0000   476.0000   497.0000    612.0000
# kneeheightsitting                516.0000   541.0000   564.0000    666.0000
# lateralfemoralepicondyleheight   463.0000   483.0000   503.0000    594.0000
# lateralmalleolusheight            65.0000    70.0000    75.0000     93.0000
# lowerthighcircumference          384.0000   405.0000   427.0000    600.0000
# mentonsellionlength              114.0000   120.0000   125.0000    156.0000
# neckcircumference                342.0000   380.0000   404.0000    514.0000
# neckcircumferencebase            382.0000   418.0000   442.0000    545.0000
# overheadfingertipreachsitting   1327.0000  1393.0000  1449.0000   1651.0000
# palmlength                       109.0000   114.0000   118.0000    140.0000
# poplitealheight                  394.0000   417.0000   438.0000    525.0000
# radialestylionlength             245.0000   260.0000   273.0000    328.0000
# shouldercircumference           1057.0000  1139.0000  1197.0000   1413.0000
# shoulderelbowlength              338.0000   355.0000   370.0000    423.0000
# shoulderlength                   137.0000   145.0000   154.0000    185.0000
# sittingheight                    866.0000   900.0000   930.0000   1039.0000
# sleevelengthspinewrist           824.0000   872.0000   910.0000   1058.0000
# sleeveoutseam                    550.0000   578.0000   603.0000    709.0000
# span                            1686.7500  1771.0000  1842.0000   2121.0000
# stature                         1651.7500  1719.0000  1779.0000   1993.0000
# suprasternaleheight             1348.0000  1407.0000  1459.0000   1650.0000
# tenthribheight                  1057.0000  1099.0000  1141.0000   1305.0000
# thighcircumference               583.0000   621.0000   659.0000    870.0000
# thighclearance                   165.0000   175.0000   187.0000    259.0000
# thumbtipreach                    753.0000   792.0000   826.0000    998.0000
# tibialheight                     437.0000   458.0000   478.0000    584.0000
# tragiontopofhead                 125.0000   130.0000   134.0000    150.0000
# trochanterionheight              845.0000   882.0000   918.0000   1095.0000
# verticaltrunkcircumferenceusa   1558.0000  1628.0000  1695.0000   1991.0000
# waistbacklength                  435.0000   463.0000   486.0000    598.0000
# waistbreadth                     292.0000   316.0000   343.0000    461.0000
# waistcircumference               829.0000   907.0000   992.0000   1379.0000
# waistdepth                       203.0000   226.0000   252.2500    406.0000
# waistfrontlengthsitting          355.0000   375.0000   398.0000    494.0000
# waistheightomphalion             988.0000  1033.0000  1076.0000   1245.0000
# weightkg                         682.0000   785.0000   896.0000   1442.0000
# wristcircumference               159.0000   170.0000   179.0000    216.0000
# wristheight                      797.0000   830.0000   863.0000   1009.0000
# SubjectNumericRace                 1.0000     1.0000     2.0000  42351.0000
# DODRace                            1.0000     1.0000     2.0000      8.0000
# Age                               23.0000    28.0000    36.0000     58.0000
# Heightin                          66.0000    68.0000    71.0000     94.0000
# Weightlbs                        150.0000   173.0000   196.0000    321.0000

# %%
df.describe().T[df.describe().T['std']>df.describe().T['mean']]
# Out:
#                        count    mean      std    min    25%    50%    75%  \
# SubjectNumericRace 6068.0000 17.5153 550.9499 1.0000 1.0000 1.0000 2.0000
#
#                           max
# SubjectNumericRace 42351.0000

# %% [markdown]
# - subjectid, SubjectNumericRace

# %%
df.describe(include='O').T
# Out:
#                       count unique                     top  freq
# Gender                 6068      2                    Male  4082
# Date                   6068    253               27-Feb-12    45
# Installation           6068     12             Camp Shelby  1160
# Component              6068      3            Regular Army  3140
# Branch                 6068      3  Combat Service Support  3174
# PrimaryMOS             6068    285                     11B   671
# SubjectsBirthLocation  6068    152              California   446
# Ethnicity              1421    209                 Mexican   357
# WritingPreference      6068      3              Right hand  5350

# %%
df.groupby(["Component"])["DODRace"].value_counts(normalize=True)
# Out:
# Component            DODRace
# Army National Guard  1         0.6850
#                      2         0.1843
#                      3         0.0934
#                      4         0.0222
#                      5         0.0089
#                      6         0.0063
# Army Reserve         1         0.5182
#                      2         0.2364
#                      3         0.1864
#                      4         0.0409
#                      6         0.0136
#                      5         0.0045
# Regular Army         1         0.5806
#                      2         0.2379
#                      3         0.1226
#                      4         0.0379
#                      6         0.0124
#                      5         0.0076
#                      8         0.0010
# Name: DODRace, dtype: float64

# %%
g = df.groupby(["Component"])["DODRace"].value_counts().sort_values().plot.barh()
g.bar_label(g.containers[0], padding=4, fontsize=13);

# %%
df[df['SubjectNumericRace']!=df['DODRace']].shape
# Out:
# (806, 108)

# %%
print(df.columns.to_list())
# Out:
# ['subjectid', 'abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth', 'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength', 'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth', 'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion', 'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength', 'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth', 'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference', 'handlength', 'headbreadth', 'headcircumference', 'headlength', 'heelanklecircumference', 'heelbreadth', 'hipbreadth', 'hipbreadthsitting', 'iliocristaleheight', 'interpupillarybreadth', 'interscyei', 'interscyeii', 'kneeheightmidpatella', 'kneeheightsitting', 'lateralfemoralepicondyleheight', 'lateralmalleolusheight', 'lowerthighcircumference', 'mentonsellionlength', 'neckcircumference', 'neckcircumferencebase', 'overheadfingertipreachsitting', 'palmlength', 'poplitealheight', 'radialestylionlength', 'shouldercircumference', 'shoulderelbowlength', 'shoulderlength', 'sittingheight', 'sleevelengthspinewrist', 'sleeveoutseam', 'span', 'stature', 'suprasternaleheight', 'tenthribheight', 'thighcircumference', 'thighclearance', 'thumbtipreach', 'tibialheight', 'tragiontopofhead', 'trochanterionheight', 'verticaltrunkcircumferenceusa', 'waistbacklength', 'waistbreadth', 'waistcircumference', 'waistdepth', 'waistfrontlengthsitting', 'waistheightomphalion', 'weightkg', 'wristcircumference', 'wristheight', 'Gender', 'Date', 'Installation', 'Component', 'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace', 'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs', 'WritingPreference']

# %%
# drop columns repeated and unnecessary column 
df.drop(columns=['subjectid', 'Date', 'Installation', 'Component', 'Branch', 'PrimaryMOS', 'SubjectNumericRace',
    'Ethnicity', 'Heightin', 'Weightlbs'], inplace=True)

# %%
df["DODRace"].value_counts().sort_index()
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 5      49
# 6      59
# 8       3
# Name: DODRace, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(16,6))
# to show the proportion of each class
g = sns.countplot(df["DODRace"])
for c in g.containers:
    # custom label calculates percent and add an empty string so 0 value bars don't have a number
    labels = [f'{h}' if (h:=v.get_height()) > 0 else '' for v in c]
    g.bar_label(c, labels=labels, fontsize=13, weight='bold', rotation=0)

# %%
df = df[df['DODRace'].isin([1,2,3])]
df['DODRace'].value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# Name: DODRace, dtype: int64

# %%
df['DODRace'].value_counts().sort_index().plot.pie(
#     subplots=True, layout=(1,2),
#     startangle=90, legend=True,
    shadow=True, figsize=(5,5),
    textprops={'fontsize':16, 'color':'k'},
    wedgeprops = {'linewidth':2, 'edgecolor':'w'},
    colors=['LightSkyBlue', 'gold', 'g', 'm'],
#     explode=[0, 0, 0, 0.1, 0.1, 0.1, 0.1],
    title='Percentage of Target',
#     labels=['Kecimen', 'Besni'],
    ylabel= "",
    labeldistance=1.1, pctdistance=0.75, 
    autopct=lambda x: '{:.0f}\n%{:.2f}'.format(len(df['DODRace'])*x/100, x), 
#     lambda x: '{:.0f}\n{:.2f}%'.format(len(df['species'])*x/100, x) 
#     "%.1f%%"
#     lambda x: f'{(x/100*len(df['species'])):.0f}\n{x:.2f}%'
)#.legend(loc='best', bbox_to_anchor=(1.0, 0.5)); # Not subplots
# Out:
# <AxesSubplot:title={'center':'Percentage of Target'}>

# %%
df.groupby('Gender')['DODRace'].value_counts().sort_index().to_frame().unstack(0)
# Out:
#         DODRace
# Gender   Female  Male
# DODRace
# 1           975  2817
# 2           656   642
# 3           239   440

# %%
g = df.groupby('Gender')['DODRace'].value_counts(normalize=True).sort_index().to_frame().unstack(0).plot.pie(
    subplots=True, layout=(1,2), 
    startangle=90, legend=False,
    shadow=True, figsize=(9, 9),
    textprops={'fontsize':16, 'color':'k'},
    wedgeprops = {'linewidth':2, 'edgecolor':'w'},
    colors=['LightSkyBlue', 'gold', 'g'],
#     explode=[0, 0, 0, 0.1, 0.1, 0.1, 0.1],
    title=["Female","Male"],
    ylabel= "",
#     labels=['Kecimen', 'Besni'],
    labeldistance=1.1, pctdistance=0.75, 
    autopct=lambda x: '{:.0f}\n%{:.2f}'.format(len(df['DODRace'])*x/100, x), 
#     lambda x: '{:.0f}\n{:.2f}%'.format(len(df['species'])*x/100, x) 
#     "%.1f%%"
#     lambda x: f'{(x/100*len(df['species'])):.0f}\n{x:.2f}%'
)#.legend(loc='best', bbox_to_anchor=(1.0, 0.5)); # Not subplots

data = df.groupby('Gender')['DODRace'].value_counts().sort_index().to_frame().unstack(0)
data_per = df.groupby('Gender')['DODRace'].value_counts(normalize=True).sort_index().to_frame().unstack(0)
for x, ra in enumerate(g.ravel()):
    index = 1
    for y, te in enumerate(ra.texts):
        if y%2:
            te.set_text(f'{data.iloc[:, x][index].round(2)}\n%{data_per.iloc[:, x][index].round(2)}')
            te.set_fontsize(12)
            index+=1

# %% [markdown]
# ## Outlier Detection

# %%
# We can produce a function to get the number of outliers respectively each class. For the sake of practicality, we find the outliers for features without consideration of class distinction
def detect_outliers(df, col_name, tukey=1.5):
    ''' 
    this function detects outliers based on 1.5 time IQR and
    returns the number of lower and uper limit and number of outliers respectively
    '''
    q1 = df[col_name].quantile(0.25)
    q3 = df[col_name].quantile(0.75)
    IQR = q3 - q1
                      
    upper_limit = q3 + (tukey*IQR)
    lower_limit = q1 - (tukey*IQR)
    outlier_count = ((df[col_name]<lower_limit) | (df[col_name]>upper_limit)).sum()
 
    return lower_limit, upper_limit, outlier_count

# %%
# iqr=3
def get_outliers_cols(df, columns, tukey=3):
    out_cols = []
    for col in columns:
        print(
            f"{detect_outliers(df, col, tukey)[2]:<3}: outlier -> {col}\
            \nlower:{detect_outliers(df, col, tukey)[0]:<10}, upper:{detect_outliers(df, col, tukey)[1]:<10}\n"
        )
        out_cols.append(col) if detect_outliers(df, col, tukey)[2] else _
            
    return out_cols

# %%
# objects = df.select_dtypes('O').columns
numbers = df.select_dtypes('number').columns

numbers.shape
# Out:
# (95,)

# %%
out_cols = get_outliers_cols(df, numbers, tukey=3)
# Out:
# 1  : outlier -> abdominalextensiondepthsitting
# lower:64.0      , upper:428.0
#
# 0  : outlier -> acromialheight
# lower:1020.0    , upper:1797.0
#
# 0  : outlier -> acromionradialelength
# lower:230.0     , upper:426.0
#
# 0  : outlier -> anklecircumference
# lower:151.0     , upper:298.0
#
# 0  : outlier -> axillaheight
# lower:955.0     , upper:1648.0
#
# 0  : outlier -> balloffootcircumference
# lower:164.0     , upper:325.0
#
# 0  : outlier -> balloffootlength
# lower:129.0     , upper:262.0
#
# 0  : outlier -> biacromialbreadth
# lower:242.0     , upper:557.0
#
# 0  : outlier -> bicepscircumferenceflexed
# lower:138.0     , upper:544.0
#
# 0  : outlier -> bicristalbreadth
# lower:184.0     , upper:366.0
#
# 0  : outlier -> bideltoidbreadth
# lower:284.0     , upper:697.0
#
# 0  : outlier -> bimalleolarbreadth
# lower:44.0      , upper:100.0
#
# 0  : outlier -> bitragionchinarc
# lower:248.0     , upper:402.0
#
# 0  : outlier -> bitragionsubmandibulararc
# lower:205.0     , upper:408.0
#
# 0  : outlier -> bizygomaticbreadth
# lower:101.0     , upper:178.0
#
# 0  : outlier -> buttockcircumference
# lower:667.0     , upper:1374.0
#
# 0  : outlier -> buttockdepth
# lower:115.0     , upper:367.0
#
# 0  : outlier -> buttockheight
# lower:612.0     , upper:1130.0
#
# 0  : outlier -> buttockkneelength
# lower:449.0     , upper:771.0
#
# 0  : outlier -> buttockpopliteallength
# lower:358.0     , upper:638.0
#
# 0  : outlier -> calfcircumference
# lower:242.0     , upper:529.0
#
# 0  : outlier -> cervicaleheight
# lower:1067.0    , upper:1893.0
#
# 0  : outlier -> chestbreadth
# lower:185.0     , upper:381.0
#
# 0  : outlier -> chestcircumference
# lower:529.0     , upper:1516.0
#
# 1  : outlier -> chestdepth
# lower:126.0     , upper:378.0
#
# 0  : outlier -> chestheight
# lower:866.0     , upper:1643.0
#
# 0  : outlier -> crotchheight
# lower:564.0     , upper:1089.0
#
# 0  : outlier -> crotchlengthomphalion
# lower:412.0     , upper:832.0
#
# 0  : outlier -> crotchlengthposterioromphalion
# lower:208.0     , upper:495.0
#
# 0  : outlier -> earbreadth
# lower:21.0      , upper:49.0
#
# 0  : outlier -> earlength
# lower:38.0      , upper:87.0
#
# 0  : outlier -> earprotrusion
# lower:8.0       , upper:36.0
#
# 0  : outlier -> elbowrestheight
# lower:108.0     , upper:374.0
#
# 0  : outlier -> eyeheightsitting
# lower:580.0     , upper:993.0
#
# 0  : outlier -> footbreadthhorizontal
# lower:64.0      , upper:134.0
#
# 0  : outlier -> footlength
# lower:180.0     , upper:348.0
#
# 0  : outlier -> forearmcenterofgriplength
# lower:224.0     , upper:455.0
#
# 0  : outlier -> forearmcircumferenceflexed
# lower:141.0     , upper:449.0
#
# 0  : outlier -> forearmforearmbreadth
# lower:234.0     , upper:871.0
#
# 0  : outlier -> forearmhandlength
# lower:324.0     , upper:611.0
#
# 0  : outlier -> functionalleglength
# lower:778.0     , upper:1429.0
#
# 0  : outlier -> handbreadth
# lower:50.0      , upper:120.0
#
# 0  : outlier -> handcircumference
# lower:120.0     , upper:288.0
#
# 0  : outlier -> handlength
# lower:137.0     , upper:242.0
#
# 0  : outlier -> headbreadth
# lower:124.0     , upper:180.0
#
# 0  : outlier -> headcircumference
# lower:483.0     , upper:658.0
#
# 0  : outlier -> headlength
# lower:158.0     , upper:235.0
#
# 0  : outlier -> heelanklecircumference
# lower:221.0     , upper:445.0
#
# 0  : outlier -> heelbreadth
# lower:43.0      , upper:99.0
#
# 2  : outlier -> hipbreadth
# lower:236.0     , upper:460.0
#
# 2  : outlier -> hipbreadthsitting
# lower:235.0     , upper:536.0
#
# 0  : outlier -> iliocristaleheight
# lower:755.0     , upper:1329.0
#
# 0  : outlier -> interpupillarybreadth
# lower:475.0     , upper:790.0
#
# 0  : outlier -> interscyei
# lower:199.0     , upper:626.0
#
# 0  : outlier -> interscyeii
# lower:237.0     , upper:629.0
#
# 0  : outlier -> kneeheightmidpatella
# lower:318.0     , upper:633.0
#
# 0  : outlier -> kneeheightsitting
# lower:373.0     , upper:709.0
#
# 0  : outlier -> lateralfemoralepicondyleheight
# lower:348.0     , upper:621.0
#
# 0  : outlier -> lateralmalleolusheight
# lower:35.0      , upper:105.0
#
# 1  : outlier -> lowerthighcircumference
# lower:255.0     , upper:556.0
#
# 0  : outlier -> mentonsellionlength
# lower:81.0      , upper:158.0
#
# 0  : outlier -> neckcircumference
# lower:153.0     , upper:594.0
#
# 0  : outlier -> neckcircumferencebase
# lower:203.0     , upper:623.0
#
# 0  : outlier -> overheadfingertipreachsitting
# lower:967.0     , upper:1814.0
#
# 0  : outlier -> palmlength
# lower:79.0      , upper:149.0
#
# 0  : outlier -> poplitealheight
# lower:263.0     , upper:571.0
#
# 0  : outlier -> radialestylionlength
# lower:165.0     , upper:354.0
#
# 0  : outlier -> shouldercircumference
# lower:639.0     , upper:1619.0
#
# 0  : outlier -> shoulderelbowlength
# lower:246.0     , upper:463.0
#
# 0  : outlier -> shoulderlength
# lower:86.0      , upper:205.0
#
# 0  : outlier -> sittingheight
# lower:675.0     , upper:1123.0
#
# 0  : outlier -> sleevelengthspinewrist
# lower:574.0     , upper:1162.0
#
# 0  : outlier -> sleeveoutseam
# lower:389.0     , upper:767.0
#
# 0  : outlier -> span
# lower:1228.0    , upper:2306.0
#
# 0  : outlier -> stature
# lower:1277.0    , upper:2159.0
#
# 0  : outlier -> suprasternaleheight
# lower:1017.0    , upper:1794.0
#
# 0  : outlier -> tenthribheight
# lower:807.0     , upper:1395.0
#
# 0  : outlier -> thighcircumference
# lower:357.0     , upper:889.0
#
# 1  : outlier -> thighclearance
# lower:103.0     , upper:250.0
#
# 0  : outlier -> thumbtipreach
# lower:532.0     , upper:1050.0
#
# 0  : outlier -> tibialheight
# lower:319.0     , upper:599.0
#
# 0  : outlier -> tragiontopofhead
# lower:98.0      , upper:161.0
#
# 0  : outlier -> trochanterionheight
# lower:628.0     , upper:1139.0
#
# 0  : outlier -> verticaltrunkcircumferenceusa
# lower:1153.0    , upper:2105.0
#
# 0  : outlier -> waistbacklength
# lower:282.0     , upper:639.0
#
# 0  : outlier -> waistbreadth
# lower:136.0     , upper:500.0
#
# 0  : outlier -> waistcircumference
# lower:339.0     , upper:1487.0
#
# 1  : outlier -> waistdepth
# lower:57.0      , upper:400.0
#
# 0  : outlier -> waistfrontlengthsitting
# lower:226.0     , upper:527.0
#
# 0  : outlier -> waistheightomphalion
# lower:729.0     , upper:1338.0
#
# 0  : outlier -> weightkg
# lower:44.0      , upper:1542.0
#
# 0  : outlier -> wristcircumference
# lower:99.0      , upper:239.0
#
# 0  : outlier -> wristheight
# lower:600.0     , upper:1062.0
#
# 0  : outlier -> DODRace
# lower:-2.0      , upper:5.0
#
# 0  : outlier -> Age
# lower:-16.0     , upper:75.0

# %%
out_cols
# Out:
# ['abdominalextensiondepthsitting',
#  'chestdepth',
#  'hipbreadth',
#  'hipbreadthsitting',
#  'lowerthighcircumference',
#  'thighclearance',
#  'waistdepth']

# %%
df1 = df.copy()

# %%
# # We have decided to drop outliers over 1,5 iqr
# for col in out_cols:
#     df = df[(df[col]>detect_outliers(df, col, tukey=1.5)[0]) & (df[col]<detect_outliers(df, col, tukey=1.5)[1])]
# df.shape

# %%
df.groupby('Gender')['DODRace'].value_counts().sort_index().to_frame().unstack(0)
# Out:
#         DODRace
# Gender   Female  Male
# DODRace
# 1           975  2817
# 2           656   642
# 3           239   440

# %%
g = sns.catplot(
    x="DODRace", data=df,  hue=None,
    kind="count", col="Gender",   
    height=6, aspect=1.1,
);
for f in g.axes.flatten():
    for c in f.containers:
        f.bar_label(c, padding=4, fontsize=14);

# %% [markdown]
# ### Numerical Columns

# %% [markdown]
# #### Hist plot All Numerical Columns

# %%
# df[numbers].hist(
#     layout=(int(np.ceil(len(numbers)/4)), 4),
#     figsize=(15, 10), bins=50, 
#     xlabelsize=12, ylabelsize=12,
#     color="darkcyan", edgecolor="black", 
# );
# plt.tight_layout()

# %%
# fig = plt.figure(figsize=(15, 10))
# for i, col in enumerate(numbers):
#     ax = plt.subplot(int(np.ceil(len(numbers)/4)), 4, i+1)
#     sns.histplot(x=col, data=df, kde=True, stat='density', ax=ax,
#         color='r', edgecolor = 'k', alpha=.6, bins=int(50),
#     )
#     plt.tight_layout()
# #     ax.bar_label(ax.containers[0], fmt='%.2f', fontsize=12, weight='bold')

# %% [markdown]
#   #### Box plot All Numerical Columns

# %%
# fig = plt.figure(figsize=(15, 10))
# for i, col in enumerate(numbers):
#     plt.subplot(int(np.ceil(len(numbers)/4)), 4, i+1)
#     sns.boxplot(y=col, data=df, whis=1.5)
#     plt.tight_layout()

# %% [markdown]
# #### Regplot plot All Numerical Columns

# %%
# # relational plot(regplot- lmplot)-residplot:
# # residplot() 
# # işlevi, basit regresyon modelinin bir veri kümesi için uygun olup olmadığını denetlemek için kullanışlı bir araç olabilir. 
# # Basit bir doğrusal regresyona uyar ve kaldırır ve ardından her gözlem için artık değerleri çizer. 
# # İdeal olarak, bu değerler rastgele etrafa dağılmalıdır:
# fig = plt.figure(figsize=(15,20))
# for i, col in enumerate(numbers):
#     plt.subplot(int(np.ceil(len(numbers)/4)), 4, i+1)
#     sns.regplot(x='price', y=col, data=df, scatter_kws={"s":8, 'alpha':0.6})
#     plt.tight_layout()

# %% [markdown]
# ### Categorical Columns

# %% [markdown]
# #### Countplot for Categorical Columns

# %%
categorical_features = [i for i in df.select_dtypes('O').columns if df[i].nunique()<15]

fig = plt.figure(figsize=(15, 5))
for i, col in enumerate(categorical_features):
    plt.subplot(int(np.ceil(len(categorical_features)/3)), 3, i+1)
    g = sns.countplot(x=df[col], alpha=0.7, data=df, palette="Set1")
    g.bar_label(g.containers[0])
#     g.tick_params(axis='x', rotation=45)
#     g.set_xticklabels(g.get_xticklabels(), rotation=45)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

# %% [markdown]
# #### Boxplots for Categorical Columns

# %%
categorical_features = [i for i in df.select_dtypes('O').columns if df[i].nunique()<15]

fig = plt.figure(figsize=(15, 5))
for i, col in enumerate(categorical_features):
    plt.subplot(int(np.ceil(len(categorical_features)/2)), 2, i+1)
    g = sns.boxplot(x=df[col], y="DODRace", data=df, palette="Spectral_r")
#     g.tick_params(axis='x', rotation=45)
#     g.set_xticklabels(g.get_xticklabels(), rotation=45)
    plt.xticks(rotation=75, ha='right', fontsize=12)
    plt.tight_layout()

# %% [markdown]
# ## Correlation between numbersal features

# %%
df.corr()[(abs(df.corr())>= 0.9) & (abs(df.corr()) < 1)].any().any()
# Out:
# True

# %%
def check_multicolinarity(data, rate=0.9):
    ''' data = numbers list like object or pd.Dataframe'''
    def color_red(val):
        color = ('red' if abs(val) >= rate and val < 1 else 'black')
        return f'color: {color}'

    df = pd.DataFrame(data)
    df_corr = df.corr().applymap(lambda x: x if abs(x)>=0.9 and x<1 else np.NaN).dropna(how='all').dropna(how='all', axis=1)
    df_corr
    
    print(f'Multicolinarity Data', df_corr.shape)
    return df_corr.style.applymap(color_red)

# check_multicolinarity(df)

# %%
df.corr().unstack().drop_duplicates().sort_values(key=abs, ascending=False).to_frame('Corr').head(5)
# Out:
#                                                                 Corr
# abdominalextensiondepthsitting abdominalextensiondepthsitting 1.0000
# cervicaleheight                stature                        0.9911
# stature                        suprasternaleheight            0.9891
# cervicaleheight                suprasternaleheight            0.9891
# acromialheight                 axillaheight                   0.9871

# %%
df.info(max_cols=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5769 entries, 0 to 6067
# Columns: 98 entries, abdominalextensiondepthsitting to WritingPreference
# dtypes: int64(95), object(3)
# memory usage: 4.4+ MB

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv("ansurII_2.csv", index = False)

# %% [markdown]
# # Prediction (Multi-class Classification)

# %% [markdown]
# If you have done, use your data set resulting from Feature Engineering task. If you haven't done Feature Engineering, use the latest version of your data set.
# In this section, you have two main tasks that apply to each algorithm:
# 1. Model Building and Prediction
#
#  - SVM (Use ``LinearSVC`` model from``sklearn.svm`` module)
#  - Decision Tree (Use ``DecisionTreeClassifier`` model from ``sklearn.tree`` module)
#  - Random Forest (Use ``RandomForestClassifier`` model from ``sklearn.ensemble`` module)
#  - XGBoost (Use ``XGBClassifier`` model from``xgboost`` module)
#
# 2. Visualizing the Result
#
# - Use [yellowbrick](https://www.scikit-yb.org/en/latest/), [seaborn](https://seaborn.pydata.org/tutorial/regression.html) or [matplotlib](https://matplotlib.org/) modules to visualize the model results.
#
# - Show three plots for the results:
#  - Class Prediction Error Bar Plot
#  - Confusion Matrix
#  - Classification Report

# %% [markdown]
# ## Import Libraries

# %%
# !pip install -U scikit-learn
# sklearn library for machine learning algorithms, data preprocessing, and evaluation
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from xgboost import XGBClassifier

# import sklearn sklearn.metrics.SCORERS.keys()
from sklearn.metrics import make_scorer, accuracy_score, recall_score, precision_score, f1_score, log_loss
from sklearn.metrics import classification_report, plot_confusion_matrix, confusion_matrix
from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import plot_roc_curve, roc_curve, roc_auc_score, auc
from sklearn.metrics import plot_precision_recall_curve, precision_recall_curve, average_precision_score
import pickle

# %%
# yellowbrick library for visualizing the model performance
from yellowbrick.cluster import KElbowVisualizer 

from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve

#!pip install scikit-plot
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall

# %% [markdown]
# ## DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %% [markdown]
# ### Features and Target variable Split
# * Splitting the dataset into X(independent variables) and y (dependent variable)

# %%
df = pd.read_csv("ansurII_2.csv")
df.shape
# Out:
# (5769, 98)

# %%
df.info(max_cols=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5769 entries, 0 to 5768
# Columns: 98 entries, abdominalextensiondepthsitting to WritingPreference
# dtypes: int64(95), object(3)
# memory usage: 4.3+ MB

# %%
X = df.drop(columns=['DODRace'])
y = df['DODRace']

# %% [markdown]
# ### Train | Test Split
# - Split the data into training and testing sets
# - get_dummies for X_train and X_test - for data separated by ','
# - OneHotEncoder for X_train and X_test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=random_state)

# %%
X_train.shape, X_test.shape, X_train.shape[0]+X_test.shape[0]
# Out:
# ((4615, 97), (1154, 97), 5769)

# %% [markdown]
# ### `OneHotEncoder` for X_train and X_test

# %%
# way-1
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler

cat = X_train.select_dtypes("object").columns.to_list()
column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore", sparse=False), cat),
    remainder=MinMaxScaler()
)

# %%
# way-2
# from sklearn.preprocessing import OneHotEncoder

# def trans_2_OneHotEncoder(X_train, X_test):
    
#     cat = X_train.select_dtypes("object").columns.to_list()    
#     enc = OneHotEncoder(handle_unknown="ignore", sparse=False)
    
#     X_train_cat = pd.DataFrame(
#         enc.fit_transform(X_train[cat]), index = X_train.index, 
#         columns = enc.get_feature_names(cat)
#     )    
#     X_test_cat  = pd.DataFrame(
#         enc.transform(X_test[cat]), index = X_test.index, 
#         columns = enc.get_feature_names(cat)
#     )    
#     X_train = X_train_cat.join(X_train.select_dtypes("number"))
#     X_test = X_test_cat.join(X_test.select_dtypes("number"))
        
#     return X_train, X_test

# X_train_enc, X_test_enc = trans_2_OneHotEncoder(X_train, X_test)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

pd.DataFrame(y_test).value_counts().sort_index()
# Out:
# 0    758
# 1    260
# 2    136
# dtype: int64

# %%
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score, f1_score, log_loss
from sklearn.metrics import plot_confusion_matrix, confusion_matrix

def eval_metric(model, X_train, y_train, X_test, y_test, model_name='', average=None, labels=None):
    """ average (None, 'micro', 'macro', 'samples', 'weighted', 'binary')"""
    # The style parameters control properties like the color of the background and whether a grid is enabled by default.
    sns.set_style("whitegrid", {'axes.grid' : False})
    y_pred_test = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    
    print("TEST")
    print(classification_report(y_test, y_pred_test))
    fig, ax = plt.subplots(2, 1, figsize=(6, 6))
    plot_confusion_matrix(model, X_test, y_test, ax=ax[0]);
    print("\n"*3, "-*"*30)
    print("TRAIN")
    print(classification_report(y_train, y_pred_train))
    plot_confusion_matrix(model, X_train, y_train, ax=ax[1]);
    plt.tight_layout()
    
    return pd.DataFrame.from_dict({
        'accuracy_test' :accuracy_score(y_test, y_pred_test),
        'f1_test'       :f1_score(y_test, y_pred_test, average=average, labels=labels)[0],
        'recall_test'   :recall_score(y_test, y_pred_test, average=average, labels=labels)[0],
        'precision_test':precision_score(y_test, y_pred_test, average=average, labels=labels)[0],        
        'accuracy_train' :accuracy_score(y_train, y_pred_train),
        'f1_train'       :f1_score(y_train, y_pred_train, average=average, labels=labels)[0],        
        'recall_train'   :recall_score(y_train, y_pred_train, average=average, labels=labels)[0],
        'precision_train':precision_score(y_train, y_pred_train, average=average, labels=labels)[0],
    }, orient='index', columns=[model_name]).T

# %% [markdown]
# ## 1. Implement Logistic Regression Model

# %% [markdown]
# ### Vanilla Logistic Regression Model

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
 
log_model = LogisticRegression(random_state=random_state) 

# pipeline for Logistic Regression
pipe_log = Pipeline([
    ("OneHotEncoder",column_trans),
    ("log", log_model)
])
pipe_log.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['Gender',
#                                                    'SubjectsBirthLocation',
#                                                    'WritingPreference'])])),
#                 ('log', LogisticRegression(random_state=42))])

# %%
eval_metric(
    pipe_log, X_train, y_train, X_test, y_test, 
    'Logistic Regression', average=None, labels=[2]
)
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       758
#            1       0.94      0.90      0.92       260
#            2       0.77      0.54      0.63       136
#
#     accuracy                           0.90      1154
#    macro avg       0.87      0.80      0.83      1154
# weighted avg       0.90      0.90      0.90      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      3034
#            1       0.95      0.92      0.93      1038
#            2       0.84      0.57      0.68       543
#
#     accuracy                           0.92      4615
#    macro avg       0.90      0.82      0.85      4615
# weighted avg       0.91      0.92      0.91      4615
#                      accuracy_test  f1_test  recall_test  precision_test  \
# Logistic Regression         0.9021   0.6320       0.5368          0.7684
#
#                      accuracy_train  f1_train  recall_train  precision_train
# Logistic Regression          0.9161    0.6805        0.5727           0.8383

# %% [markdown]
# ### Cross Validate Model
# * Use the cross_val_score function to evaluate the model using the train set.

# %%
# import sklearn 
# sklearn.metrics.SCORERS.keys()

# %%
from sklearn.model_selection import cross_validate, cross_val_score

log_model = LogisticRegression(random_state=random_state)

# pipeline for Cross Validate
model = Pipeline([
    ("OneHotEncoder",column_trans),
    ("log",log_model)
]) 
scoring = {
    "f1_2" : make_scorer(f1_score, average = None, labels=[2]),
    "recall_2" : make_scorer(recall_score, average = None, labels=[2]),
    "precision_2" : make_scorer(precision_score, average = None, labels=[2]),
}
scores = cross_validate(
    model, X_train, y_train, 
    scoring = scoring, # ['accuracy', 'f1_macro', 'precision_macro','recall_macro'], 
    error_score="raise",
    n_jobs=-1,
    cv=5,
)
df_scores = pd.DataFrame.from_dict(scores, orient='columns')
df_scores.mean()[2:]
# Out:
# test_f1_2          0.6379
# test_recall_2      0.5378
# test_precision_2   0.7921
# dtype: float64

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

log_model = LogisticRegression(random_state=random_state)

# pipeline for GridsearchCV
model = Pipeline([
    ("OneHotEncoder",column_trans),
    ("log",log_model)
])
param_grid = {
    "log__penalty" : ['l1'],
    "log__C" : np.linspace(4, 5, 3),
    "log__class_weight" : ["balanced"],
    "log__solver" : ['liblinear', 'sag', 'saga', 'lbfgs'], # ['liblinear', 'sag', 'saga', 'lbfgs', 'newton-cg']
}
f1_2 = make_scorer(f1_score, average = None, labels=[2])
recall_2 = make_scorer(recall_score, average = None, labels=[2])
grid_model = GridSearchCV(
    estimator=model,
    param_grid = param_grid, 
    scoring=recall_2, # 'f1_macro'
#     error_score="raise",
    n_jobs=-1,
    cv=5
) 
# grid_model.estimator.get_params().keys()

# %%
# %%time
grid_model.fit(X_train, y_train)
# Out:
# CPU times: user 5.54 s, sys: 62.4 ms, total: 5.6 s
# Wall time: 1min 59s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          ['Gender',
#                                                                           'SubjectsBirthLocation',
#                                                                           'WritingPreference'])])),
#                                        ('log',
#                                         LogisticRegression(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'log__C': array([4. , 4.5, 5. ]),
#                          'log__class_weight': ['balanced'],
#                          'log__penalty': ['l1'],
#                          'log__solver': ['liblinear', 'sag', 'saga', 'lbfgs']},
#              scoring=make_scorer(recall_score, average=None, labels=[2]))

# %%
grid_model.best_params_ # default accuracy score
# Out:
# {'log__C': 4.5,
#  'log__class_weight': 'balanced',
#  'log__penalty': 'l1',
#  'log__solver': 'saga'}

# %%
grid_model.best_score_
# Out:
# 0.7625722052327558

# %%
out_score_log = eval_metric(
    grid_model, X_train, y_train, X_test, y_test,
    'Logistic Regression', average=None, labels=[2]
)
out_score_log
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.91       758
#            1       0.92      0.92      0.92       260
#            2       0.56      0.81      0.66       136
#
#     accuracy                           0.88      1154
#    macro avg       0.81      0.87      0.83      1154
# weighted avg       0.90      0.88      0.89      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91      3034
#            1       0.93      0.95      0.94      1038
#            2       0.55      0.85      0.67       543
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.89      0.84      4615
# weighted avg       0.91      0.88      0.89      4615
#                      accuracy_test  f1_test  recall_test  precision_test  \
# Logistic Regression         0.8795   0.6627       0.8088          0.5612
#
#                      accuracy_train  f1_train  recall_train  precision_train
# Logistic Regression          0.8810    0.6676        0.8545           0.5478

# %% [markdown]
# # Distance Based Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Implement K-Nearest Neighbors(KNN) Model

# %%
# !pip install threadpoolctl==3.1.0

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

knn_model = KNeighborsClassifier() 

# pipeline for KNeighbors Classifier regression
pipe_knn = Pipeline([
    ("OneHotEncoder",column_trans),
    ("knn", knn_model)
]) 
pipe_knn.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['Gender',
#                                                    'SubjectsBirthLocation',
#                                                    'WritingPreference'])])),
#                 ('knn', KNeighborsClassifier())])

# %%
eval_metric(
    pipe_knn, X_train, y_train, X_test, y_test, 
    'knn', average=None, labels=[2]
)
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86       758
#            1       0.80      0.57      0.66       260
#            2       0.65      0.36      0.46       136
#
#     accuracy                           0.78      1154
#    macro avg       0.75      0.62      0.66      1154
# weighted avg       0.78      0.78      0.77      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      3034
#            1       0.89      0.65      0.75      1038
#            2       0.86      0.51      0.64       543
#
#     accuracy                           0.84      4615
#    macro avg       0.86      0.71      0.76      4615
# weighted avg       0.85      0.84      0.83      4615
#      accuracy_test  f1_test  recall_test  precision_test  accuracy_train  \
# knn         0.7842   0.4645       0.3603          0.6533          0.8420
#
#      f1_train  recall_train  precision_train
# knn    0.6429        0.5138           0.8585

# %% [markdown]
# ### Overfiting and underfiting control for k values

# %%
def elbow_method(K):
    test_error_rates = []
    train_error_rates = []

    for k in K: 
        knn_model = KNeighborsClassifier(n_neighbors=k)
        # pipeline for KNeighbors Classifier regression
        pipe_knn = Pipeline([
            ("OneHotEncoder",column_trans),
            ("knn", knn_model)
        ]) 
        pipe_knn.fit(X_train , y_train)
        y_pred_test = pipe_knn.predict(X_test)
        y_pred_train = pipe_knn.predict(X_train)
        
        # test setindeki hatayı bulmak için
        test_error = 1-accuracy_score(y_test, y_pred_test)  
        train_error = 1-accuracy_score(y_train, y_pred_train)
        test_error_rates.append(test_error)
        train_error_rates.append(train_error)
        
    return test_error_rates, train_error_rates

test_error_rates, train_error_rates = elbow_method(K)

# %% [markdown]
# ### Cross Validate Model

# %%
from sklearn.model_selection import cross_validate, cross_val_score

knn_model = KNeighborsClassifier(n_neighbors=5) 

# pipeline for Cross Validate
model = Pipeline([
    ("OneHotEncoder",column_trans),
    ("knn", knn_model)
])  
scoring = {
    "f1_2" : make_scorer(f1_score, average = None, labels=[2]),
    "recall_2" : make_scorer(recall_score, average = None, labels=[2]),
    "precision_2" : make_scorer(precision_score, average = None, labels=[2]),
}
scores = cross_validate(
    model, X_train, y_train, 
    scoring = scoring, # ['accuracy', 'f1_macro', 'precision_macro','recall_macro'], 
    error_score="raise",
    n_jobs=-1,
    cv=5,
)
df_scores = pd.DataFrame.from_dict(scores, orient='columns')
df_scores.mean()[2:]
# Out:
# test_f1_2          0.4987
# test_recall_2      0.3849
# test_precision_2   0.7167
# dtype: float64

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %%
from sklearn.model_selection import GridSearchCV

knn_model = KNeighborsClassifier()  

# pipeline for GridsearchCV
model = Pipeline([
    ("OneHotEncoder",column_trans),
    ("knn", knn_model)
])
param_grid = {
    'knn__n_neighbors': range(3,9),
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski'],
    'knn__p': [1,2],
#     'knn__leaf_size': [30],
#     'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
}
f1_2 = make_scorer(f1_score, average = None, labels=[2])
recall_2 = make_scorer(recall_score, average = None, labels=[2])
grid_model = GridSearchCV(
    estimator=model,
    param_grid = param_grid, 
    error_score="raise",
    scoring=recall_2,
    n_jobs=-1,
    cv=5
) 
# grid_model.estimator.get_params().keys()

# %%
# %%time
grid_model.fit(X_train, y_train)
# Out:
# CPU times: user 1.46 s, sys: 129 ms, total: 1.59 s
# Wall time: 38.4 s
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          ['Gender',
#                                                                           'SubjectsBirthLocation',
#                                                                           'WritingPreference'])])),
#                                        ('knn', KNeighborsClassifier())]),
#              n_jobs=-1,
#              param_grid={'knn__metric': ['minkowski'],
#                          'knn__n_neighbors': range(3, 9), 'knn__p': [1, 2],
#                          'knn__weights': ['uniform', 'distance']},
#              scoring=make_scorer(recall_score, average=None, labels=[2]))

# %%
grid_model.best_params_
# Out:
# {'knn__metric': 'minkowski',
#  'knn__n_neighbors': 3,
#  'knn__p': 2,
#  'knn__weights': 'distance'}

# %%
grid_model.best_score_
# Out:
# 0.44753652735304106

# %%
out_score_knn = eval_metric(
    grid_model, X_train, y_train, X_test, y_test, 
    'K-Nearest Neighbors', average=None, labels=[2]
)
out_score_knn
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       758
#            1       0.75      0.60      0.67       260
#            2       0.52      0.45      0.48       136
#
#     accuracy                           0.77      1154
#    macro avg       0.69      0.65      0.67      1154
# weighted avg       0.77      0.77      0.77      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3034
#            1       1.00      1.00      1.00      1038
#            2       1.00      1.00      1.00       543
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615
#                      accuracy_test  f1_test  recall_test  precision_test  \
# K-Nearest Neighbors         0.7730   0.4803       0.4485          0.5169
#
#                      accuracy_train  f1_train  recall_train  precision_train
# K-Nearest Neighbors          1.0000    1.0000        1.0000           1.0000

# %% [markdown]
# ## 2. Implement Support Vector Machine Model

# %% [markdown]
# ### Vanilla  LinearSVC model

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import BaggingClassifier
from sklearn.pipeline import Pipeline

svc_model = LinearSVC(random_state=random_state)   

# pipeline for SVC regression
pipe_svc = Pipeline([
    ("OneHotEncoder",column_trans),
    ("svc", svc_model)
]) 
pipe_svc.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['Gender',
#                                                    'SubjectsBirthLocation',
#                                                    'WritingPreference'])])),
#                 ('svc', LinearSVC(random_state=42))])

# %%
eval_metric(
    pipe_svc, X_train, y_train, X_test, y_test, 
    'SVC', average=None, labels=[2]
)
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       758
#            1       0.92      0.92      0.92       260
#            2       0.85      0.54      0.66       136
#
#     accuracy                           0.91      1154
#    macro avg       0.89      0.81      0.84      1154
# weighted avg       0.91      0.91      0.90      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      3034
#            1       0.95      0.94      0.94      1038
#            2       0.86      0.56      0.68       543
#
#     accuracy                           0.92      4615
#    macro avg       0.91      0.82      0.86      4615
# weighted avg       0.92      0.92      0.91      4615
#      accuracy_test  f1_test  recall_test  precision_test  accuracy_train  \
# SVC         0.9090   0.6637       0.5441          0.8506          0.9194
#
#      f1_train  recall_train  precision_train
# SVC    0.6756        0.5562           0.8604

# %% [markdown]
# ### Cross Validate Model

# %%
from sklearn.model_selection import cross_validate, cross_val_score

svc_model = LinearSVC(random_state=random_state)  

# pipeline for Cross Validate
model = Pipeline([
    ("OneHotEncoder",column_trans),
    ("svc", svc_model)
])  
scoring = {
    "f1_2" : make_scorer(f1_score, average = None, labels=[2]),
    "recall_2" : make_scorer(recall_score, average = None, labels=[2]),
    "precision_2" : make_scorer(precision_score, average = None, labels=[2]),
}
scores = cross_validate(
    model, X_train, y_train, 
    scoring = scoring, # ['accuracy', 'f1_macro', 'precision_macro','recall_macro'], 
    error_score="raise",
    n_jobs=-1,
    cv=5,
)
df_scores = pd.DataFrame.from_dict(scores, orient='columns')
df_scores.mean()[2:]
# Out:
# test_f1_2          0.6365
# test_recall_2      0.5213
# test_precision_2   0.8272
# dtype: float64

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %%
from sklearn.model_selection import GridSearchCV

# probability True to obtain ROC etc.
svc_model = SVC(probability=True, random_state=random_state)  

# pipeline for GridsearchCV
model = Pipeline([
    ("OneHotEncoder",column_trans),
    ("svc", svc_model)
])
param_grid = {
    'svc__C': np.linspace(2, 3, 3),
    'svc__gamma': ["scale"], # ['scale', 'auto', 0.1, 1]
#     'svc__kernel': ['poly'], # ['linear', 'poly', 'rbf']
#     'svc__degree': [2],
    'svc__class_weight': ['balanced'], # [None, "balanced"]
    'svc__decision_function_shape': ['ovo'], # ['ovo', 'ovr']
     
}
f1_2 = make_scorer(f1_score, average = None, labels=[2])
recall_2 = make_scorer(recall_score, average = None, labels=[2])
grid_model = GridSearchCV(
    estimator=model,
    param_grid = param_grid, 
    error_score="raise",
    scoring=recall_2,
    n_jobs=-1,
    cv=5
) 
# grid_model.estimator.get_params().keys()

# %%
# %%time
grid_model.fit(X_train, y_train)
# Out:
# CPU times: user 14.2 s, sys: 104 ms, total: 14.3 s
# Wall time: 1min 46s
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          ['Gender',
#                                                                           'SubjectsBirthLocation',
#                                                                           'WritingPreference'])])),
#                                        ('svc',
#                                         SVC(probability=True,
#                                             random_state=42))]),
#              n_jobs=-1,
#              param_grid={'svc__C': array([2. , 2.5, 3. ]),
#                          'svc__class_weight': ['balanced'],
#                          'svc__decision_function_shape': ['ovo'],
#                          'svc__gamma': ['scale']},
#              scoring=make_scorer(recall_score, average=None, labels=[2]))

# %%
grid_model.best_params_
# Out:
# {'svc__C': 3.0,
#  'svc__class_weight': 'balanced',
#  'svc__decision_function_shape': 'ovo',
#  'svc__gamma': 'scale'}

# %%
grid_model.best_score_
# Out:
# 0.7662079510703365

# %%
out_score_svc = eval_metric(
    grid_model, X_train, y_train, X_test, y_test, 
    'SVC', average=None, labels=[2]
)
out_score_svc
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.91       758
#            1       0.91      0.92      0.91       260
#            2       0.53      0.77      0.63       136
#
#     accuracy                           0.87      1154
#    macro avg       0.80      0.85      0.82      1154
# weighted avg       0.90      0.87      0.88      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92      3034
#            1       0.94      0.94      0.94      1038
#            2       0.56      0.88      0.68       543
#
#     accuracy                           0.89      4615
#    macro avg       0.82      0.90      0.85      4615
# weighted avg       0.91      0.89      0.90      4615
#      accuracy_test  f1_test  recall_test  precision_test  accuracy_train  \
# SVC         0.8726   0.6306       0.7721          0.5330          0.8878
#
#      f1_train  recall_train  precision_train
# SVC    0.6834        0.8766           0.5600

# %% [markdown]
# ## 3. Implement Bagging Classifier - Support Vector Machine Model

# %% [markdown]
# ### Vanilla  Bagging - LinearSVC model

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import BaggingClassifier
from sklearn.pipeline import Pipeline

svc_model = LinearSVC(random_state=random_state)  
bag_svc_model = BaggingClassifier(svc_model) 

# pipeline for SVC regression
pipe_bag_svc = Pipeline([
    ("OneHotEncoder",column_trans),
    ("bag_svc", bag_svc_model)
]) 
pipe_bag_svc.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['Gender',
#                                                    'SubjectsBirthLocation',
#                                                    'WritingPreference'])])),
#                 ('bag_svc',
#                  BaggingClassifier(base_estimator=LinearSVC(random_state=42)))])

# %%
eval_metric(
    pipe_bag_svc, X_train, y_train, X_test, y_test, 
    'Bagging SVC', average=None, labels=[2]
)
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       758
#            1       0.92      0.90      0.91       260
#            2       0.83      0.52      0.64       136
#
#     accuracy                           0.90      1154
#    macro avg       0.89      0.80      0.83      1154
# weighted avg       0.90      0.90      0.90      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      3034
#            1       0.95      0.93      0.94      1038
#            2       0.85      0.56      0.68       543
#
#     accuracy                           0.92      4615
#    macro avg       0.90      0.82      0.85      4615
# weighted avg       0.92      0.92      0.91      4615
#              accuracy_test  f1_test  recall_test  precision_test  \
# Bagging SVC         0.9038   0.6396       0.5221          0.8256
#
#              accuracy_train  f1_train  recall_train  precision_train
# Bagging SVC          0.9183    0.6763        0.5617           0.8496

# %% [markdown]
# ### Cross Validate Model

# %%
from sklearn.model_selection import cross_validate, cross_val_score

svc_model = LinearSVC(random_state=random_state)  
bag_svc_model = BaggingClassifier(svc_model)

# pipeline for Cross Validate
model = Pipeline([
    ("OneHotEncoder",column_trans),
    ("bag_svc", bag_svc_model)
])  
scoring = {
    "f1_2" : make_scorer(f1_score, average = None, labels=[2]),
    "recall_2" : make_scorer(recall_score, average = None, labels=[2]),
    "precision_2" : make_scorer(precision_score, average = None, labels=[2]),
}
scores = cross_validate(
    model, X_train, y_train, 
    scoring = scoring, # ['accuracy', 'f1_macro', 'precision_macro','recall_macro'], 
    error_score="raise",
    n_jobs=-1,
    cv=5,
)
df_scores = pd.DataFrame.from_dict(scores, orient='columns')
df_scores.mean()[2:]
# Out:
# test_f1_2          0.6296
# test_recall_2      0.5213
# test_precision_2   0.8030
# dtype: float64

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %%
from sklearn.model_selection import GridSearchCV

# probability True to obtain ROC etc.
svc_model = SVC(probability=True, random_state=random_state)  
bag_svc_model = BaggingClassifier(svc_model) 

# pipeline for GridsearchCV
model = Pipeline([
    ("OneHotEncoder",column_trans),
    ("bag_svc", bag_svc_model)
])
param_grid = {
    # BaggingClassifier # n_estimators*max_samples > data
    'bag_svc__n_estimators': [5],
    'bag_svc__max_samples': [1.0],
    # SVC
    'bag_svc__base_estimator__C': np.linspace(3, 4, 2),
#     'bag_svc__base_estimator__gamma': ['scale'],
#     'bag_svc__base_estimator__kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
#     'bag_svc__base_estimator__degree': [2],
    'bag_svc__base_estimator__class_weight': ['balanced'], # [None, "balanced"]
    'bag_svc__base_estimator__decision_function_shape': ['ovo'], # ['ovo', 'ovr']
}
f1_2 = make_scorer(f1_score, average = None, labels=[2])
recall_2 = make_scorer(recall_score, average = None, labels=[2])
grid_model = GridSearchCV(
    estimator=model,
    param_grid = param_grid, 
    error_score="raise",
    scoring=recall_2,
    n_jobs=-1,
    cv=5
) 
# grid_model.estimator.get_params().keys()

# %%
# %%time
grid_model.fit(X_train, y_train)
# Out:
# CPU times: user 31.3 s, sys: 199 ms, total: 31.5 s
# Wall time: 3min 4s
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          ['Gender',
#                                                                           'SubjectsBirthLocation',
#                                                                           'WritingPreference'])])),
#                                        ('bag_svc',
#                                         BaggingClassifier(base_estimator=SVC(probability=True,
#                                                                              random_state=42)))]),
#              n_jobs=-1,
#              param_grid={'bag_svc__base_estimator__C': array([3., 4.]),
#                          'bag_svc__base_estimator__class_weight': ['balanced'],
#                          'bag_svc__base_estimator__decision_function_shape': ['ovo'],
#                          'bag_svc__max_samples': [1.0],
#                          'bag_svc__n_estimators': [5]},
#              scoring=make_scorer(recall_score, average=None, labels=[2]))

# %%
grid_model.best_params_
# Out:
# {'bag_svc__base_estimator__C': 3.0,
#  'bag_svc__base_estimator__class_weight': 'balanced',
#  'bag_svc__base_estimator__decision_function_shape': 'ovo',
#  'bag_svc__max_samples': 1.0,
#  'bag_svc__n_estimators': 5}

# %%
grid_model.best_score_
# Out:
# 0.5194529391777098

# %%
out_score_bag_svc = eval_metric(
    grid_model, X_train, y_train, X_test, y_test, 
    'Bagging SVC', average=None, labels=[2]
)
out_score_bag_svc
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       758
#            1       0.93      0.92      0.92       260
#            2       0.82      0.51      0.63       136
#
#     accuracy                           0.91      1154
#    macro avg       0.89      0.80      0.83      1154
# weighted avg       0.90      0.91      0.90      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      3034
#            1       0.95      0.94      0.95      1038
#            2       0.81      0.64      0.72       543
#
#     accuracy                           0.92      4615
#    macro avg       0.90      0.85      0.87      4615
# weighted avg       0.92      0.92      0.92      4615
#              accuracy_test  f1_test  recall_test  precision_test  \
# Bagging SVC         0.9081   0.6335       0.5147          0.8235
#
#              accuracy_train  f1_train  recall_train  precision_train
# Bagging SVC          0.9231    0.7159        0.6427           0.8079

# %% [markdown]
# # Tree Based Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %%
df = pd.read_csv("ansurII_2.csv")
df.shape
# Out:
# (5769, 98)

# %%
df.info(max_cols=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5769 entries, 0 to 5768
# Columns: 98 entries, abdominalextensiondepthsitting to WritingPreference
# dtypes: int64(95), object(3)
# memory usage: 4.3+ MB

# %%
X = df.drop(columns=['DODRace'])
y = df['DODRace']

# %% [markdown]
# ### Train | Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=random_state)

# %% [markdown]
# ### `OrdinalEncoder` for Decision Tree Classifier Based Models

# %%
# way-1
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder

cat = X_train.select_dtypes("object").columns.to_list()    
column_trans = make_column_transformer(
    (OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), cat), 
    remainder='passthrough'
)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

pd.DataFrame(y_test).value_counts().sort_index()
# Out:
# 0    758
# 1    260
# 2    136
# dtype: int64

# %% [markdown]
# ## 1. Implement Decision Tree Classifier Model
# - Import the modul
# - Fit the model
# - Predict the test set
# - Visualize and evaluate the result (use yellowbrick module)

# %% [markdown]
# ### Vanilla DT Model

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.pipeline import Pipeline

dt_model = DecisionTreeClassifier(random_state=random_state)

# pipeline for DecisionTree Classifier
pipe_dt = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("dt", dt_model)
])
pipe_dt.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['Gender',
#                                                    'SubjectsBirthLocation',
#                                                    'WritingPreference'])])),
#                 ('dt', DecisionTreeClassifier(random_state=42))])

# %%
eval_metric(
    pipe_dt, X_train, y_train, X_test, y_test, 
    'Decision Tree', average=None, labels=[2]
)
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       758
#            1       0.63      0.66      0.64       260
#            2       0.18      0.21      0.20       136
#
#     accuracy                           0.68      1154
#    macro avg       0.54      0.55      0.54      1154
# weighted avg       0.69      0.68      0.68      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3034
#            1       1.00      1.00      1.00      1038
#            2       1.00      1.00      1.00       543
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615
#                accuracy_test  f1_test  recall_test  precision_test  \
# Decision Tree         0.6776   0.1959       0.2132          0.1812
#
#                accuracy_train  f1_train  recall_train  precision_train
# Decision Tree          1.0000    1.0000        1.0000           1.0000

# %% [markdown]
# ### Cross Validate Model

# %%
from sklearn.model_selection import cross_validate, cross_val_score

dt_model = DecisionTreeClassifier(random_state=random_state)

# pipeline for Cross Validate
model = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("dt", dt_model)
])  
scoring = {
    "f1_2" : make_scorer(f1_score, average = None, labels=[2]),
    "recall_2" : make_scorer(recall_score, average = None, labels=[2]),
    "precision_2" : make_scorer(precision_score, average = None, labels=[2]),
}
scores = cross_validate(
    model, X_train, y_train, 
    scoring = scoring, # ['accuracy', 'f1_macro', 'precision_macro','recall_macro'], 
    error_score="raise",
    n_jobs=-1,
    cv=5,
)
df_scores = pd.DataFrame.from_dict(scores, orient='columns')
df_scores.mean()[2:]
# Out:
# test_f1_2          0.1993
# test_recall_2      0.2044
# test_precision_2   0.1949
# dtype: float64

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %%
from sklearn.model_selection import GridSearchCV

dt_model = DecisionTreeClassifier(random_state=random_state)

# pipeline for GridsearchCV
model = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("dt", dt_model)
])
param_grid = {
    "dt__class_weight" : ["balanced"], # [None, "balanced"]
    "dt__criterion" : ["gini", "entropy"], 
    "dt__splitter": ["best"], # ["best", "random"]
    "dt__max_features":["auto", "log2"], # [None, "auto", "log2", .3, .5]
    "dt__max_depth": [None, 1, 2],
    "dt__min_samples_split": [2, 3],
    "dt__min_samples_leaf": [1, 2, 3],
}
f1_2 = make_scorer(f1_score, average = None, labels=[2])
recall_2 = make_scorer(recall_score, average = None, labels=[2])
grid_model = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    error_score="raise",
    scoring=recall_2, 
    n_jobs=-1,
    cv=5,
)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['Gender',
#                                                                           'SubjectsBirthLocation',
#                                                                           'WritingPreference'])])),
#                                        ('dt',
#                                         DecisionTreeClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'dt__class_weight': ['balanced'],
#                          'dt__criterion': ['gini', 'entropy'],
#                          'dt__max_depth': [None, 1, 2],
#                          'dt__max_features': ['auto', 'log2'],
#                          'dt__min_samples_leaf': [1, 2, 3],
#                          'dt__min_samples_split': [2, 3],
#                          'dt__splitter': ['best']},
#              scoring=make_scorer(recall_score, average=None, labels=[2]))

# %%
grid_model.best_params_
# Out:
# {'dt__class_weight': 'balanced',
#  'dt__criterion': 'entropy',
#  'dt__max_depth': 1,
#  'dt__max_features': 'log2',
#  'dt__min_samples_leaf': 1,
#  'dt__min_samples_split': 2,
#  'dt__splitter': 'best'}

# %%
grid_model.best_score_
# Out:
# 0.8949711179068978

# %%
out_score_dt = eval_metric(
    grid_model, X_train, y_train, X_test, y_test, 
    'Decision Tree', average=None, labels=[2]
)
out_score_dt
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.78      0.34      0.47       758
#            1       0.00      0.00      0.00       260
#            2       0.14      0.87      0.25       136
#
#     accuracy                           0.33      1154
#    macro avg       0.31      0.40      0.24      1154
# weighted avg       0.53      0.33      0.34      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.77      0.31      0.44      3034
#            1       0.00      0.00      0.00      1038
#            2       0.14      0.90      0.25       543
#
#     accuracy                           0.31      4615
#    macro avg       0.30      0.40      0.23      4615
# weighted avg       0.52      0.31      0.32      4615
#                accuracy_test  f1_test  recall_test  precision_test  \
# Decision Tree         0.3267   0.2466       0.8676          0.1437
#
#                accuracy_train  f1_train  recall_train  precision_train
# Decision Tree          0.3112    0.2494        0.9024           0.1447

# %% [markdown]
# ## 2. Implement Bagging Classifier Model
# - Import the modul
# - Fit the model
# - Predict the test set
# - Visualize and evaluate the result (use yellowbrick module)

# %% [markdown]
# ### Vanilla Bagging - Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.pipeline import Pipeline

dt_model = DecisionTreeClassifier(random_state=random_state)
bag_dt_model = BaggingClassifier(dt_model)

# pipeline for Bagging Classifier
pipe_bag_dt = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("bag_dt", bag_dt_model)
])
pipe_bag_dt.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['Gender',
#                                                    'SubjectsBirthLocation',
#                                                    'WritingPreference'])])),
#                 ('bag_dt',
#                  BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=42)))])

# %%
eval_metric(
    pipe_bag_dt, X_train, y_train, X_test, y_test, 
    'Bagging Decision Tree', average=None, labels=[2]
)
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88       758
#            1       0.80      0.73      0.76       260
#            2       0.44      0.14      0.21       136
#
#     accuracy                           0.80      1154
#    macro avg       0.69      0.60      0.62      1154
# weighted avg       0.77      0.80      0.77      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3034
#            1       0.99      0.99      0.99      1038
#            2       0.99      0.90      0.94       543
#
#     accuracy                           0.98      4615
#    macro avg       0.99      0.96      0.97      4615
# weighted avg       0.98      0.98      0.98      4615
#                        accuracy_test  f1_test  recall_test  precision_test  \
# Bagging Decision Tree         0.7998   0.2123       0.1397          0.4419
#
#                        accuracy_train  f1_train  recall_train  precision_train
# Bagging Decision Tree          0.9840    0.9439        0.8987           0.9939

# %% [markdown]
# ### Cross Validate Model

# %%
from sklearn.model_selection import cross_validate, cross_val_score

dt_model = DecisionTreeClassifier(random_state=random_state)
bag_dt_model = BaggingClassifier(dt_model)

# pipeline for Cross Validate
model = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("bag_dt", bag_dt_model)
])  
scoring = {
    "f1_2" : make_scorer(f1_score, average = None, labels=[2]),
    "recall_2" : make_scorer(recall_score, average = None, labels=[2]),
    "precision_2" : make_scorer(precision_score, average = None, labels=[2]),
}
scores = cross_validate(
    model, X_train, y_train, 
    scoring = scoring, # ['accuracy', 'f1_macro', 'precision_macro','recall_macro'], 
    error_score="raise",
    n_jobs=-1,
    cv=5,
)
df_scores = pd.DataFrame.from_dict(scores, orient='columns')
df_scores.mean()[2:]
# Out:
# test_f1_2          0.1450
# test_recall_2      0.0940
# test_precision_2   0.3241
# dtype: float64

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %% [markdown]
# {'dt__class_weight': 'balanced',
#  'dt__criterion': 'entropy',
#  'dt__max_depth': 1,
#  'dt__max_features': 'log2',
#  'dt__min_samples_leaf': 1,
#  'dt__min_samples_split': 2,
#  'dt__splitter': 'best'}

# %%
from sklearn.model_selection import GridSearchCV

dt_model = DecisionTreeClassifier(random_state=random_state)
bag_dt_model = BaggingClassifier(dt_model)

# pipeline for GridsearchCV
model = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("bag_dt", bag_dt_model)
])
param_grid = {
    # BaggingClassifier
    "bag_dt__n_estimators": [45],
    "bag_dt__max_samples": [1.0],
    # DecisionTreeClassifier
    "bag_dt__base_estimator__class_weight" : ["balanced"], # [None, "balanced"]
    "bag_dt__base_estimator__criterion" : ["gini", "entropy"], 
    "bag_dt__base_estimator__splitter":["best"], # ["best", "random"]
    "bag_dt__base_estimator__max_depth": [1],
    "bag_dt__base_estimator__max_features":["log2"], # [None, "auto", "log2", .3, .5]
    "bag_dt__base_estimator__min_samples_split": [2],
    "bag_dt__base_estimator__min_samples_leaf": [3],
}
f1_2 = make_scorer(f1_score, average = None, labels=[2])
recall_2 = make_scorer(recall_score, average = None, labels=[2])
grid_model = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    error_score="raise",
    scoring=recall_2, 
    n_jobs=-1,
    cv=5,
)
# grid_model.estimator.get_params().keys()

# %%
# %%time
grid_model.fit(X_train, y_train)
# Out:
# CPU times: user 597 ms, sys: 114 ms, total: 711 ms
# Wall time: 5 s
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['Gender',
#                                                                           'SubjectsBirthLocation',
#                                                                           'WritingPreference'])])),
#                                        ('bag_dt',
#                                         BaggingClassifier(base_estimator=DecisionTreeClassifier(r...
#                                                                'entropy'],
#                          'bag_dt__base_estimator__max_depth': [1],
#                          'bag_dt__base_estimator__max_features': ['log2'],
#                          'bag_dt__base_estimator__min_samples_leaf': [3],
#                          'bag_dt__base_estimator__min_samples_split': [2],
#                          'bag_dt__base_estimator__splitter': ['best'],
#                          'bag_dt__max_samples': [1.0],
#                          'bag_dt__n_estimators': [45]},
#              scoring=make_scorer(recall_score, average=None, labels=[2]))

# %%
grid_model.best_params_
# Out:
# {'bag_dt__base_estimator__class_weight': 'balanced',
#  'bag_dt__base_estimator__criterion': 'entropy',
#  'bag_dt__base_estimator__max_depth': 1,
#  'bag_dt__base_estimator__max_features': 'log2',
#  'bag_dt__base_estimator__min_samples_leaf': 3,
#  'bag_dt__base_estimator__min_samples_split': 2,
#  'bag_dt__base_estimator__splitter': 'best',
#  'bag_dt__max_samples': 1.0,
#  'bag_dt__n_estimators': 45}

# %%
grid_model.best_score_
# Out:
# 0.7607033639143731

# %%
out_score_bag_dt = eval_metric(
    grid_model, X_train, y_train, X_test, y_test, 
    'Bagging Decision Tree', average=None, labels=[2]
)
out_score_bag_dt
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.86      0.33      0.48       758
#            1       0.43      0.40      0.41       260
#            2       0.16      0.74      0.27       136
#
#     accuracy                           0.39      1154
#    macro avg       0.48      0.49      0.38      1154
# weighted avg       0.68      0.39      0.44      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.88      0.33      0.48      3034
#            1       0.51      0.46      0.48      1038
#            2       0.17      0.77      0.27       543
#
#     accuracy                           0.41      4615
#    macro avg       0.52      0.52      0.41      4615
# weighted avg       0.71      0.41      0.46      4615
#                        accuracy_test  f1_test  recall_test  precision_test  \
# Bagging Decision Tree         0.3934   0.2658       0.7426          0.1619
#
#                        accuracy_train  f1_train  recall_train  precision_train
# Bagging Decision Tree          0.4126    0.2729        0.7716           0.1657

# %% [markdown]
# ## 3. Implement RF Classifier Model
# - Import the modul
# - Fit the model
# - Predict the test set
# - Visualize and evaluate the result (use yellowbrick module)

# %% [markdown]
# ### Vanilla RF Model

# %%
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.pipeline import Pipeline

rfc_model = RandomForestClassifier(random_state=random_state)

# pipeline for Random Forest Classifier
pipe_rfc = Pipeline([
    ("OrdinalEncoder", column_trans), 
    ("rfc", rfc_model)
])
pipe_rfc.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['Gender',
#                                                    'SubjectsBirthLocation',
#                                                    'WritingPreference'])])),
#                 ('rfc', RandomForestClassifier(random_state=42))])

# %%
eval_metric(
    pipe_dt, X_train, y_train, X_test, y_test, 
    'Random Forest', average=None, labels=[2]
)
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       758
#            1       0.63      0.66      0.64       260
#            2       0.18      0.21      0.20       136
#
#     accuracy                           0.68      1154
#    macro avg       0.54      0.55      0.54      1154
# weighted avg       0.69      0.68      0.68      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3034
#            1       1.00      1.00      1.00      1038
#            2       1.00      1.00      1.00       543
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615
#                accuracy_test  f1_test  recall_test  precision_test  \
# Random Forest         0.6776   0.1959       0.2132          0.1812
#
#                accuracy_train  f1_train  recall_train  precision_train
# Random Forest          1.0000    1.0000        1.0000           1.0000

# %% [markdown]
# ### Cross Validate Model

# %%
from sklearn.model_selection import cross_validate, cross_val_score

rfc_model = RandomForestClassifier(random_state=random_state)

# pipeline for Cross Validate
model = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("rfc", rfc_model)
])  
scoring = {
    "f1_2" : make_scorer(f1_score, average = None, labels=[2]),
    "recall_2" : make_scorer(recall_score, average = None, labels=[2]),
    "precision_2" : make_scorer(precision_score, average = None, labels=[2]),
}
scores = cross_validate(
    model, X_train, y_train, 
    scoring = scoring, # ['accuracy', 'f1_macro', 'precision_macro','recall_macro'], 
    error_score="raise",
    n_jobs=-1,
    cv=5,
)
df_scores = pd.DataFrame.from_dict(scores, orient='columns')
df_scores.mean()[2:]
# Out:
# test_f1_2          0.0925
# test_recall_2      0.0497
# test_precision_2   0.7117
# dtype: float64

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %%
from sklearn.model_selection import GridSearchCV

rfc_model = RandomForestClassifier(random_state=random_state)

# pipeline for GridsearchCV
model = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("rfc", rfc_model)
])
param_grid = {
    'rfc__max_depth': [1,2], 
    'rfc__n_estimators': [10],
    'rfc__criterion': ["gini", "entropy"],
#     'rfc__max_features': [None, 'auto', .1, .2],
    'rfc__class_weight': ['balanced'], # [None, 'balanced']
}
f1_2 = make_scorer(f1_score, average = None, labels=[2])
recall_2 = make_scorer(recall_score, average = None, labels=[2])
grid_model = GridSearchCV(
    estimator=model,
    param_grid = param_grid, 
    error_score="raise",
    scoring=recall_2,
    refit=True,
    verbose=2,
    n_jobs=-1,
    cv=5,
)

# %%
# %%time
grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# CPU times: user 137 ms, sys: 13.8 ms, total: 151 ms
# Wall time: 556 ms
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['Gender',
#                                                                           'SubjectsBirthLocation',
#                                                                           'WritingPreference'])])),
#                                        ('rfc',
#                                         RandomForestClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'rfc__class_weight': ['balanced'],
#                          'rfc__criterion': ['gini', 'entropy'],
#                          'rfc__max_depth': [1, 2], 'rfc__n_estimators': [10]},
#              scoring=make_scorer(recall_score, average=None, labels=[2]),
#              verbose=2)

# %%
grid_model.best_params_
# Out:
# {'rfc__class_weight': 'balanced',
#  'rfc__criterion': 'entropy',
#  'rfc__max_depth': 1,
#  'rfc__n_estimators': 10}

# %%
grid_model.best_score_
# Out:
# 0.7588854909955828

# %%
out_score_rfc = eval_metric(
    grid_model, X_train, y_train, X_test, y_test, 
    'Random Forest', average=None, labels=[2]
)
out_score_rfc
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.87      0.24      0.38       758
#            1       0.38      0.43      0.41       260
#            2       0.16      0.75      0.26       136
#
#     accuracy                           0.35      1154
#    macro avg       0.47      0.47      0.35      1154
# weighted avg       0.68      0.35      0.37      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.87      0.26      0.39      3034
#            1       0.45      0.48      0.47      1038
#            2       0.16      0.77      0.26       543
#
#     accuracy                           0.37      4615
#    macro avg       0.49      0.50      0.37      4615
# weighted avg       0.69      0.37      0.40      4615
#                accuracy_test  f1_test  recall_test  precision_test  \
# Random Forest         0.3458   0.2602       0.7500          0.1574
#
#                accuracy_train  f1_train  recall_train  precision_train
# Random Forest          0.3660    0.2628        0.7680           0.1585

# %% [markdown]
# ## 4. Implement XGBoost Classifier Model
# - Import the modul
# - Fit the model
# - Predict the test set
# - Visualize and evaluate the result (use yellowbrick module)

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline

xgb_model = XGBClassifier(random_state=random_state)

# pipeline for XGBClassifier Classifier
pipe_xgb = Pipeline([
    ("OrdinalEncoder", column_trans), 
    ("xgb", xgb_model)
])

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
classes_weights
# Out:
# array([0.50703142, 0.50703142, 0.50703142, ..., 1.4820167 , 0.50703142,
#        1.4820167 ])

# %%
comp = pd.DataFrame(classes_weights)

comp["label"] = pd.DataFrame(y_train).reset_index(drop=True)
comp.groupby("label")[0].value_counts()
# Out:
# label  0
# 0      0.5070    3034
# 1      1.4820    1038
# 2      2.8330     543
# Name: 0, dtype: int64

# %%
pipe_xgb.fit(
    X_train, y_train, 
    xgb__sample_weight=classes_weights
)
# weight parameter in XGBoost is per instance not per class. 
# Therefore, we need to assign the weight of each class to its instances, which is the same thing.
# Out:
# [23:29:22] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_44tbtwf8c1/croots/recipe/xgboost-split_1659548960882/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['Gender',
#                                                    'SubjectsBirthLocation',
#                                                    'WritingPreference'])])),
#                 ('xgb',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, enab...
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=8, num_parallel_tree=1,
#                                objective='multi:softprob', predictor='auto',
#                                random_state=42, reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=None, subsample=1,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %%
eval_metric(
    pipe_xgb, X_train, y_train, X_test, y_test, 
    'XGBoost', average=None, labels=[2]
)
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93       758
#            1       0.90      0.88      0.89       260
#            2       0.78      0.46      0.57       136
#
#     accuracy                           0.89      1154
#    macro avg       0.86      0.77      0.80      1154
# weighted avg       0.88      0.89      0.88      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3034
#            1       1.00      1.00      1.00      1038
#            2       1.00      1.00      1.00       543
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615
#          accuracy_test  f1_test  recall_test  precision_test  accuracy_train  \
# XGBoost         0.8865   0.5741       0.4559          0.7750          1.0000
#
#          f1_train  recall_train  precision_train
# XGBoost    1.0000        1.0000           1.0000

# %% [markdown]
# ### Cross Validate Model

# %%
from sklearn.model_selection import cross_validate, cross_val_score

xgb_model = XGBClassifier(random_state=random_state)

# pipeline for Cross Validate
model = Pipeline(steps=[
    ("OrdinalEncoder", column_trans), 
    ("xgb", xgb_model)
])  
scoring = {
    "f1_2" : make_scorer(f1_score, average = None, labels=[2]),
    "recall_2" : make_scorer(recall_score, average = None, labels=[2]),
    "precision_2" : make_scorer(precision_score, average = None, labels=[2]),
}
scores = cross_validate(
    model, X_train, y_train, 
    scoring = scoring, # ['accuracy', 'f1_macro', 'precision_macro','recall_macro'], 
    error_score="raise",
    n_jobs=-1,
    cv=5,
    fit_params={"xgb__sample_weight":classes_weights}
)
df_scores = pd.DataFrame.from_dict(scores, orient='columns')
df_scores.mean()[2:]
# Out:
# test_f1_2          0.5363
# test_recall_2      0.4347
# test_precision_2   0.7006
# dtype: float64

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %%
from sklearn.model_selection import GridSearchCV

xgb_model = XGBClassifier(random_state=random_state)

# pipeline for GridsearchCV
model = Pipeline([
    ("OrdinalEncoder", column_trans), 
    ("xgb", xgb_model)
]) 
param_grid = {
    'xgb__n_estimators':[20],
    'xgb__learning_rate': [0.5],
    'xgb__max_depth':[1,2],
    'xgb__subsample': [1.0],
    'xgb__colsample_bytree': [0.4, 0.7],
    'xgb__min_child_weight' : [5, 8],
#     'xgb__min_split_loss': [1],
#     'xgb__reg_lambda' : [1, 2],
#     'xgb__grow_policy': ['depthwise'],
#     'xgb__eval_metric' : ["merror"],
}
f1_2 = make_scorer(f1_score, average = None, labels=[2])
recall_2 = make_scorer(recall_score, average = None, labels=[2])
grid_model = GridSearchCV(
    estimator=model,
    param_grid = param_grid, 
    error_score="raise",
    verbose=1,
    scoring=recall_2,
    refit=True,
    n_jobs=-1
)

# %%
# %%time
grid_model.fit(
    X_train, y_train, 
    xgb__sample_weight=classes_weights
)
# weight parameter in XGBoost is per instance not per class. 
# Therefore, we need to assign the weight of each class to its instances, which is the same thing.
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [23:30:26] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_44tbtwf8c1/croots/recipe/xgboost-split_1659548960882/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CPU times: user 2.3 s, sys: 181 ms, total: 2.48 s
# Wall time: 7.76 s
# GridSearchCV(error_score='raise',
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['Gender',
#                                                                           'SubjectsBirthLocation',
#                                                                           'WritingPreference'])])),
#                                        ('xgb',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       colsample_bylevel=None...
#                                                       scale_pos_weight=None,
#                                                       subsample=None,
#                                                       tree_method=None,
#                                                       validate_parameters=None,
#                                                       verbosity=None))]),
#              n_jobs=-1,
#              param_grid={'xgb__colsample_bytree': [0.4, 0.7],
#                          'xgb__learning_rate': [0.5], 'xgb__max_depth': [1, 2],
#                          'xgb__min_child_weight': [5, 8],
#                          'xgb__n_estimators': [20], 'xgb__subsample': [1.0]},
#              scoring=make_scorer(recall_score, average=None, labels=[2]),
#              verbose=1)

# %%
# xgb_grid_model.get_params().keys()
grid_model.best_params_
# Out:
# {'xgb__colsample_bytree': 0.4,
#  'xgb__learning_rate': 0.5,
#  'xgb__max_depth': 2,
#  'xgb__min_child_weight': 5,
#  'xgb__n_estimators': 20,
#  'xgb__subsample': 1.0}

# %%
out_score_xgb = eval_metric(
    grid_model, X_train, y_train, X_test, y_test, 
    'XGBoost', average=None, labels=[2]
)
out_score_xgb
# Out:
# TEST
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85       758
#            1       0.81      0.84      0.83       260
#            2       0.38      0.68      0.49       136
#
#     accuracy                           0.79      1154
#    macro avg       0.71      0.77      0.72      1154
# weighted avg       0.84      0.79      0.80      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      3034
#            1       0.81      0.89      0.85      1038
#            2       0.42      0.74      0.54       543
#
#     accuracy                           0.80      4615
#    macro avg       0.72      0.80      0.75      4615
# weighted avg       0.85      0.80      0.81      4615
#          accuracy_test  f1_test  recall_test  precision_test  accuracy_train  \
# XGBoost         0.7877   0.4881       0.6765          0.3817          0.8007
#
#          f1_train  recall_train  precision_train
# XGBoost    0.5402        0.7422           0.4247

# %%
from yellowbrick.classifier import ClassificationReport
visualizer = ClassificationReport(grid_model, support=True)
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'GridSearchCV Classification Report'}>

# %%
visualizer = ClassPredictionError(grid_model)
# Fit the training data to the visualizer
visualizer.fit(X_train, y_train)
# Evaluate the model on the test data
visualizer.score(X_test, y_test)
# Draw visualization
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Class Prediction Error for GridSearchCV'}, xlabel='actual class', ylabel='number of predicted class'>

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve)

# %%
from sklearn.metrics import plot_roc_curve, roc_curve, roc_auc_score, auc
from sklearn.metrics import plot_precision_recall_curve, precision_recall_curve, average_precision_score

# %%
from yellowbrick.classifier import ROCAUC
model = grid_model

visualizer = ROCAUC(model)
visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
from yellowbrick.classifier import PrecisionRecallCurve
model = grid_model

viz = PrecisionRecallCurve(
    model,
    per_class=True,
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [23:30:40] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_44tbtwf8c1/croots/recipe/xgboost-split_1659548960882/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [23:30:47] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_44tbtwf8c1/croots/recipe/xgboost-split_1659548960882/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [23:30:53] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_44tbtwf8c1/croots/recipe/xgboost-split_1659548960882/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Compare The Models
#
# So far, you have created a multi-classifier model with 4 different algorithms and made predictions. You can observe the performance of the models together with a barplot of your choice.
#
# - Which algorithm did you achieve the highest prediction performance with?
# - What could be the factors that cause this? What are the principles of the most successful algorithm and its differences from other algorithms?
#
# In contrast;
#
# - Which algorithm did you achieve the lowest prediction performance with?
# - What could be the factors that cause this? What are the principles of the most successful algorithm and its differences from other algorithms?
#
# The answers you will look for to these questions will increase your gains from Machine Learning course.

# %%
compare = pd.concat([
    out_score_log, out_score_knn, out_score_svc, out_score_bag_svc, 
    out_score_dt, out_score_bag_dt, out_score_rfc, out_score_xgb,
])
compare
# Out:
#                        accuracy_test  f1_test  recall_test  precision_test  \
# Logistic Regression           0.8795   0.6627       0.8088          0.5612
# K-Nearest Neighbors           0.7730   0.4803       0.4485          0.5169
# SVC                           0.8726   0.6306       0.7721          0.5330
# Bagging SVC                   0.9081   0.6335       0.5147          0.8235
# Decision Tree                 0.3267   0.2466       0.8676          0.1437
# Bagging Decision Tree         0.3934   0.2658       0.7426          0.1619
# Random Forest                 0.3458   0.2602       0.7500          0.1574
# XGBoost                       0.7877   0.4881       0.6765          0.3817
#
#                        accuracy_train  f1_train  recall_train  precision_train
# Logistic Regression            0.8810    0.6676        0.8545           0.5478
# K-Nearest Neighbors            1.0000    1.0000        1.0000           1.0000
# SVC                            0.8878    0.6834        0.8766           0.5600
# Bagging SVC                    0.9231    0.7159        0.6427           0.8079
# Decision Tree                  0.3112    0.2494        0.9024           0.1447
# Bagging Decision Tree          0.4126    0.2729        0.7716           0.1657
# Random Forest                  0.3660    0.2628        0.7680           0.1585
# XGBoost                        0.8007    0.5402        0.7422           0.4247

# %% [markdown]
# ##  Recall Score Comparison

# %%
compare = compare.sort_values(by='recall_test', ascending=False)

plt.figure(figsize=(15,4))
ax = sns.barplot(x='recall_test', y=compare.index, data=compare.round(3), palette="plasma")
ax.bar_label(ax.containers[0], fontsize=18, color='w', weight='bold', label_type='center', rotation=0)

plt.title("Test Recall Score of Different Models", size=14)
plt.yticks(size = 14)
plt.xticks(size = 14)
plt.show()

# %% [markdown]
# ##  F1 Score Comparison

# %%
compare = compare.sort_values(by='f1_test', ascending=False)

plt.figure(figsize=(15,4))
ax = sns.barplot(x='f1_test', y=compare.index, data=compare.round(3), palette="tab20b_r")
ax.bar_label(ax.containers[0], fontsize=18, color='w', weight='bold', label_type='center', rotation=0)

plt.title("Test F1 Score of Different Models", size=14)
plt.yticks(size = 14)
plt.xticks(size = 14)
plt.show()

# %% [markdown]
# ##  Accuracy Comparison

# %%
compare = compare.sort_values(by='accuracy_test', ascending=False)

plt.figure(figsize=(15,4))
ax = sns.barplot(x='accuracy_test', y=compare.index, data=compare.round(3), palette="gnuplot")
ax.bar_label(ax.containers[0], fontsize=18, color='w', weight='bold', label_type='center', rotation=0)

plt.title("Test Accuracy Score of Different Models", size=14)
plt.yticks(size = 14)
plt.xticks(size = 14)
plt.show()

# %% [markdown]
# ##  Precision Score Comparison

# %%
compare = compare.sort_values(by='precision_test', ascending=False)

plt.figure(figsize=(15,4))
ax = sns.barplot(x='precision_test', y=compare.index, data=compare.round(3), palette="gist_rainbow_r")
ax.bar_label(ax.containers[0], fontsize=18, color='w', weight='bold', label_type='center', rotation=0)

plt.title("Test Precision Score of Different Models", size=14)
plt.yticks(size = 14)
plt.xticks(size = 14)
plt.show()

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
